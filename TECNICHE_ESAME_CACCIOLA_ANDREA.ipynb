# %% [markdown]
# # Tecniche di modellizzazione e rappresentazione dati¶

# %% [markdown]
# ## Andrea Cacciola A.A. 2023/2024

# %% [markdown]
# ## Esercizio Parameter Regression

# %% [markdown]
# ### Obiettivo

# %% [markdown]
# Data la funzione  𝑆𝐹𝑅𝐷=𝑓(𝑧,𝜃⃗ )
#   che indica il tasso di formazione stellare per unità di volume, l'obiettivo dell'esercizio è quello di ricavare i valori del vettore  𝜃⃗
#  = 𝑓−1(𝑆𝐹𝑅𝐷(𝑧))
#   con un approssimazione di una rete neurale.
# $$𝜃⃗ =(\Omega_𝑚, \sigma_8,𝐴_{𝑆𝑁1}, 𝐴_{𝑆𝑁2},𝐴_{𝐴𝐺𝑁1},𝐴_{𝐴𝐺𝑁2})$$
#
# I primi due parametri sono parametri cosmologici legati alla densità di materia e all'ampiezza delle fluttuazioni del campo di materia a , mentre i restanti 4 parametrisono parametri astrofisici legati all'efficienza dei feedback energetici da espolosioni di supernovae e nuclei galattici attivi

# %% [markdown]
# ### SFRD vs Redshift per 5 simulazioni

# %% [markdown]
# Dopo aver importato tutte le librerie di Python che saranno utili per la risoluzione del problema

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import optuna
import sys,os,time
import pandas
import torch
import torch.nn as nn
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torch.optim import lr_scheduler

# %% [markdown]
# Sono stati scaricati e letti i file forniti contenenti i dati relativi alla funzione SFRD dipendente dal redshift z e i dati relativi ai parametri cosmologici. Inoltre il file .npy è stato trasformato in un file .txt perchè di più semplice apertura

# %%
sfrd_data = np.loadtxt(r'C:\Users\Admin\Documents\Python Scripts\SFRH_IllustrisTNG.txt')
parameters_data = np.loadtxt(r'C:\Users\Admin\Downloads\params_IllustrisTNG.txt')

# %% [markdown]
# Per visualizzare i parametri letti dai file precedentemente, vengono graficati gli istogrammi con i loro valori

# %%
plt.figure(figsize=(9,9))
label = [r'$\Omega_{m}$',r'$\sigma_{8}$',r'$A_{SN1}$',r'$A_{SN2}$',r'$A_{AGN1}$',r'$A_{AGN2}$' ]
tablet = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple','tab:blue' ]
for j in range(6):
    plt.subplot(3, 2, j + 1)
    plt.hist(parameters_data[:, j], bins=100, color=tablet[j], edgecolor='black')

# Aggiungi etichette e titolo
    plt.xlabel('Valori del parametro')
    plt.ylabel('Frequenza')
    plt.title(label[j])
plt.tight_layout()
# Mostra l'istogramma
plt.show()

# %% [markdown]
# Estraggo 5 valori tra le simulazioni fornite e definisco l'array del redshift come scritto sul testo

# %%
# generazione di interi casuali in [0,999]
# Per selezionare casualmente 5 simulazioni utilizzo il comando di numpy random.choice.
#L'argomento replace=False indica che non vogliamo che gli indici siano sostituiti dopo essere stati selezionati, quindi ogni indice sarà unico
indices = np.random.choice(len(sfrd_data), size=5, replace=False)
indices
# estrazione degli elementi corrispondenti agli indici selezionati

selected_sfrd = sfrd_data[indices]
selected_parameters = parameters_data[indices]
# Con il comando linspace costruisco un array composto da una serie di 100 elementi numerici equidistribuiti tra 0 e 7.
z = np.linspace(0.0, 7.0, 100)

# %% [markdown]
# Costruisco il grafico della SFRD in funzione dei redshift

# %%
#Assegno il nome agli assi
plt.xlabel('Redshift')
plt.ylabel(r'$SFRD[M_\odot { yr}^{-1}{ Mpc}^{-3}]$')
#Assegno il nome del titolo al grafico
plt.title('SFRD vs Redshift for 5 Selected Simulations')
#Costruisco una paletta di 5 colori per distinguere ogni simulazione
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

for i in range(5):
    plt.plot(z, selected_sfrd[i], color=colors[i])
#Inserisco una legenda che identifica per ogni simulazione effettuata i corrispondenti valori dei parametri cosmologici e astrofisici
#f'Simulation {i+1}' è una forma di formattazione della stringa che combina la parte statica "Simulation " con l'indice dell'iterazione i+1 per creare etichette uniche per le curve nel grafico.
#In questo caso, i+1 rappresenta l'indice dell'iterazione nel ciclo. Poiché Python usa indicizzazione partendo da 0, aggiungiamo 1 per ottenere gli indici da 1 a 5 anziché da 0 a 4. 
#Quindi, f'Simulation {i+1}' le stringhe: Simulation 1, Simulation 2, Simulation 3, Simulation 4, Simulation 5
legend_labels = []
for i in range(5):
    legend_labels.append(f'Simulation {i+1}: {selected_parameters[i]}')
#Con il comando bbox_to_anchor=(1.8, 1.0) ho posizionato la legenda al di fuori del grafico in modo che sia situata a 1.8 unità oltre l'angolo superiore destro del grafico e 1.0 unità sopra. 
#In questo modo, la legenda verrà posizionata fuori dal grafico e non sovrapporrà le curve.
plt.legend(legend_labels, loc='upper right',bbox_to_anchor=(1.8, 1.0)) 
plt.show()

# %% [markdown]
# ### Costruzione della classe make_dataset() con suddivisione del data set

# %% [markdown]
# In questa sezione i dati forniti verranno preparati per essere analizzati dalla rete neuronale. Le reti neurali lavorano con un batch size anziché con l'intero set di dati per diverse ragioni. In primo luogo, lavorare con un intero set di dati richiederebbe molta memoria, specialmente se il dataset è grande. Inoltre, l'uso di un batch size può stabilizzare l'addestramento e prevenire l'instabilità. I batch size più grandi spesso portano a una convergenza più rapida del modello rispetto ai batch size più piccoli o all'utilizzo dell'intero dataset. E' anche importante mischiare i dati perchè potrebbero essere presenti pattern di correlazione tra i campioni adiacenti nel dataset. Questo potrebbe portare a un addestramento non ottimale, poiché la rete potrebbe imparare a riconoscere eccessivamente questi pattern locali piuttosto che modelli più generali. Uso il pacchetto Dataloader di Pytorch che aiuta a caricare i dati in batch durante l'addestramento dei modelli di deep learning e definisco un set di parametri utili per la rete neuronale. In generale, sarebbe meglio spostare gli elementi di pytorch dalla cpu alla gpu perchè la scheda grafica del computer è più veloce a eseguire le operazioni fatte.  Tuttavia, PyTorch non supporta ufficialmente l'accelerazione hardware su GPU AMD attraverso l'uso di ROCm (Radeon Open Compute), pertanto non è possibile eseguire questa operazione.Infatti, attualmente PyTorch supporta principalmente le GPU NVIDIA attraverso CUDA.

# %% [markdown]
# Definisco due variabili contenenti il percorso del file di testo

# %%
file_sfrd         = r'C:\Users\Admin\Documents\Python Scripts\SFRH_IllustrisTNG.txt'  
file_parameters       = r'C:\Users\Admin\Downloads\params_IllustrisTNG.txt'

# %%
# definizione del set di parametri e iperparametri

seed           = 1            #parametro che serve a mischiare i dati prima di dividerli in training, validation e test
min_valid_loss = 1e7          #valore molto alto della valid loss iniziale             
batch_size     = 32           # numero di elementi per ciascun batch
lr             = 0.0001         # learning rate
wd             = 0.0          # weight decay
dr             = 0.1          # dropout rate
epochs         = 300          # numero di epoche
hidden_size    = 120           #numero di neuroni per strato
patience       = 100          #Numero di epoche senza migliorare la funzione di perdita da attendere prima di aggiornare il learning rate
stop_criterion = 200          #Numero di epoche senza migliorare la funzione di perdita da attendere prima di interrompere l'addestramento

f_model        = 'best_model.pt'

# %%
# preparazione dei dati

def create_dataset(mode, file_sfrd, file_parameters, batch_size, seed):
    data_set = make_dataset(mode, file_sfrd, file_parameters, seed)
    return DataLoader(dataset = data_set, batch_size = batch_size, shuffle = True)

# %% [markdown]
# La creazione della classe make_dataset è fatta per suddividere il set di dati.Tuttavia è importante, dapprima, normalizzare i valori dei parametri e standardizzare i valori della funzione perchè può migliorare la stabilità numerica durante l'addestramento del modello. Ciò significa che le operazioni numeriche eseguite durante l'addestramento possono essere eseguite in modo più efficiente e con meno rischio di overflow o underflow.
# Il training set è il set di dati utilizzato per addestrare il modello di una rete neurale. Durante il processo di addestramento, il modello "impara" dai dati di questo set attraverso la regolarizzazione dei parametri del modello.
# Il validation set è utilizzato per regolare gli iperparametri del modello e valutare le sue prestazioni durante il processo di addestramento. È separato dal training set e contiene esempi di dati non utilizzati per l'addestramento. Dopo ogni epoca o iterazione di addestramento, il modello viene valutato sul validation set per monitorare le sue prestazioni e regolare gli iperparametri  per migliorare le prestazioni del modello. Il validation set aiuta a evitare l'overfitting, poiché fornisce una misura oggettiva delle prestazioni del modello su dati non utilizzati durante l'addestramento.
# Il test set è utilizzato per valutare le prestazioni finali del modello dopo che è stato addestrato e regolato utilizzando il training e il validation set.
# È completamente separato dal training e dal validation set e non è utilizzato durante il processo di addestramento.
# Il test set rappresenta un insieme indipendente di dati che il modello non ha mai visto prima.
# Viene utilizzato per valutare le prestazioni del modello su dati "nuovi" e fornire una stima accurata delle sue capacità di generalizzazione su dati non visti.

# %%
class make_dataset():
    def __init__(self, mode, file_sfrd, file_parameters, seed):

        sfrd_data = np.loadtxt(file_sfrd)
        parameters_data = np.loadtxt(file_parameters)

        # standardizzazione della funzione
        sfrd_data[np.where(sfrd_data==0.0)] = 1e-12  # sostituzione di eventuali valori nulli
        mean = np.mean(sfrd_data, axis=0, dtype=np.float64)
        std  = np.std(sfrd_data,  axis=0, dtype=np.float64)
        sfrd_data = (sfrd_data - mean)/std

        # normalizzazione dei  parametri
        min_parameters = np.min(parameters_data, axis=0)
        max_parameters = np.max(parameters_data, axis=0)
        parameters_data = (parameters_data - min_parameters)/(max_parameters - min_parameters)

        n_training = sfrd_data.shape[0]
        columns = sfrd_data.shape[1]

        # divisione del campione
        if   mode=='train':
            size, offset = int(n_training*0.70), int(n_training*0.00)
        elif mode=='valid':
            size, offset = int(n_training*0.15), int(n_training*0.70)
        elif mode=='test':
            size, offset = int(n_training*0.15), int(n_training*0.85)
        elif mode=='all':
            size, offset = int(n_training*1.00), int(n_training*0.00)
        else:    raise Exception('Wrong name!')

        # definizione dei tensori di input e output inizialmente nulli
        self.size   = size
        self.input  = torch.zeros((size,columns), dtype=torch.float) # SFRD
        self.output = torch.zeros((size,6), dtype=torch.float) # parametri

        # mescolamento dei dati
        np.random.seed(seed)
        indexes = np.arange(n_training)
        np.random.shuffle(indexes)
        indexes = indexes[offset:offset+size]

        # creazione degli array di input e output
        self.input  = torch.tensor(sfrd_data[indexes], dtype=torch.float32)
        self.output = torch.tensor(parameters_data[indexes], dtype=torch.float32)

    def __len__(self):
        return self.size

    def __getitem__(self, idx):
        return self.input[idx], self.output[idx]

# %% [markdown]
# Dove nell'ultima parte del codice len(self), restituisce la lunghezza totale del dataset. Mentre getitem(self, idx) restituisce l'input e l'output del campione corrispondente all'indice idx nel dataset quando accedi al dataset utilizzando dataset[idx]. Questi due metodi sono fondamentali quando si lavora con dataset personalizzati in PyTorch, poiché consentono di utilizzare la sintassi familiare delle liste o degli array per accedere ai campioni nel dataset.

# %%
train_loader = create_dataset('train', file_sfrd, file_parameters, batch_size, seed) #training dataset
valid_loader = create_dataset('valid', file_sfrd, file_parameters, batch_size, seed) #validation dataset

# %% [markdown]
# ### Costruzione della rete neuronale per predirre i valori dei parametri

# %% [markdown]
# Utilizzo un architettura del tipo nn.Linear, intervallata da una funzione di attivazione ReLu per la costruzione della rete. Nei modelli di rete neurale, la funzione di attivazione viene utilizzata per introdurre non linearità nel modello. Senza una funzione di attivazione, la rete sarebbe solo una combinazione lineare di strati, e quindi sarebbe in grado di apprendere solo relazioni lineari tra le variabili di input e di output. L'introduzione di non linearità tramite funzioni di attivazione consente alla rete neurale di apprendere relazioni complesse tra le variabili di input e di output. La funzione ReLU (Rectified Linear Unit) è un buon esempio di funzione di attivazione perché è semplice ed efficiente. Essa è definita come $$ReLu=max(0,x)$$ In questa face dell'esercizio ho scelto un numero arbitrario per gli iperparametri, lasciando l'ottimizzazione di essi alla sezione successiva. In questo caso ho scelto di costruire una rete con 4 strati nascosti e 120 neuroni per ogni strato

# %%
model = nn.Sequential(
            nn.Linear(100, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 6))

# %% [markdown]
# Nella seguente cella viene definita la loss function e l'ottimizzatore

# %%
# definizione di loss function e ottimizzatore

loss_func = nn.MSELoss()  #mean square error 
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=(0.5, 0.999), weight_decay=wd)

# %% [markdown]
# L'ottimizzatore Adam (Adaptive Moment Estimation) adatta il learnin rate o durante l'allenamento per ogni parametro, il chè lo rende adatto per problemi in cui i gradienti possono variare notevolmente

# %% [markdown]
# Durante l'addestramento, il modello utilizza il training set per aggiornare i suoi pesi e i suoi parametri in modo da minimizzare una funzione detta funzione di perdita. Nel caso in esame, è stata considera la loss function mean square error $𝐿(\vec{\theta})=\frac{1}{N} \sum_{i} (\vec{\theta}_{𝑁𝑁}-\vec{\theta}_{𝑇𝑟𝑢𝑒})^2$
#
# Questo processo avviene attraverso la discesa del gradiente. Dopo aver calcolato il gradiente, aggiorno i valori dei parametri nella direzione opposta al gradiente della loss function. $\theta_{i+1}=\theta_𝑖-\lambda \nabla_{\theta} 𝐿(\theta)$
# Dove 𝜆 è il learning rate (tasso di apprendimento), ossia un iperparametro che controlla la dimensione dei passi che un modello di machine learning prende durante l'ottimizzazione. In sostanza, determina quanto velocemente il modello cerca di imparare dai dati durante il processo di addestramento. Nel caso di algoritmi di ottimizzazione come la discesa del gradiente per aggiornare i pesi del modello durante l'addestramento, il learning rate indica la dimensione di ciascun passo in direzione opposta al gradiente. Un learning rate troppo piccolo può rallentare l'addestramento, mentre un learning rate troppo grande può causare oscillazioni o addirittura la divergenza del modello. Quindi, trovare il giusto learning rate è cruciale per l'addestramento efficace di un modello.

# %%
start = time.time() # avvio cronometro

train_value=np.zeros(epochs)
valid_value=np.zeros(epochs)

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=patience,
                                           min_lr= 1.0e-6, verbose=True)
epoch_best_model = 0

for epoch in range(epochs):

    # training
    train_loss, points = 0.0, 0 # la variabile points tiene conto della quantità
                                # di dati analizzati ad ogni epoca ed è utile per
                                # calcolare il valor medio della loss function
    model.train()
    for sfrd_train, parameters_train in train_loader:

        # dimensione del batch
        bs = sfrd_train.shape[0]

      

        # calcolo del valore previsto dalla rete
        parameters_pred  = model(sfrd_train)

        # calcolo della loss function
        loss = loss_func(parameters_pred, parameters_train)
        train_loss = train_loss + (loss.item())*bs # .item() estrae lo scalare dal tensore
        points = points + bs

        # ottimizzazione dei parametri
        optimizer.zero_grad() # azzeramento del gradiente
        loss.backward()       # calcolo del nuovo gradiente
        optimizer.step()      # calcolo dei nuovi parametri usando l'algoritmo di ottimizzazione

    # calcolo del valor medio
    train_loss = train_loss/points
    train_value[epoch] = train_loss

    # validation
    valid_loss, points = 0.0, 0
    model.eval()
    for sfrd_val, parameters_val in valid_loader:
        with torch.no_grad():   # siccome il valore del gradiente non è necessario,
                                # esso non viene calcolato per non occupare memoria
                                # inutilmente

            # dimensione del batch
            bs = sfrd_val.shape[0]

           
            # calcolo del valore previsto dalla rete
            parameters_pred = model(sfrd_val)
            
            valid_loss += (loss_func(parameters_pred, parameters_val).item())*bs
            points     = points + bs

    # calcolo del valor medio
    valid_loss /= points
    valid_value[epoch]=valid_loss

    scheduler.step(valid_loss)

    # ricerca del modello migliore
    print(f'epoch:{epoch}, valid loss: {valid_loss:.4f}', end='')
    if valid_loss<min_valid_loss:
        torch.save(model.state_dict(), f_model)
        min_valid_loss = valid_loss
        epoch_best_model=epoch
        print(' (best-model)')
    else:
        print('')
    if epoch - epoch_best_model > stop_criterion:
        print ('Training stop at epoch:',epoch,' because the best model does not imporved after ',stop_criterion,' epochs')
        break

stop = time.time() # spegnimento cronometro
print('Time taken (seconds):', "{:.4f}".format(stop-start))
# Out:
# epoch:0, valid loss: 0.1905 (best-model)
# epoch:1, valid loss: 0.1205 (best-model)
# epoch:2, valid loss: 0.0878 (best-model)
# epoch:3, valid loss: 0.0793 (best-model)
# epoch:4, valid loss: 0.0739 (best-model)
# epoch:5, valid loss: 0.0681 (best-model)
# epoch:6, valid loss: 0.0638 (best-model)
# epoch:7, valid loss: 0.0609 (best-model)
# epoch:8, valid loss: 0.0583 (best-model)
# epoch:9, valid loss: 0.0568 (best-model)
# epoch:10, valid loss: 0.0560 (best-model)
# epoch:11, valid loss: 0.0557 (best-model)
# epoch:12, valid loss: 0.0545 (best-model)
# epoch:13, valid loss: 0.0540 (best-model)
# epoch:14, valid loss: 0.0536 (best-model)
# epoch:15, valid loss: 0.0540
# epoch:16, valid loss: 0.0531 (best-model)
# epoch:17, valid loss: 0.0528 (best-model)
# epoch:18, valid loss: 0.0528 (best-model)
# epoch:19, valid loss: 0.0526 (best-model)
# epoch:20, valid loss: 0.0527
# epoch:21, valid loss: 0.0527
# epoch:22, valid loss: 0.0530
# epoch:23, valid loss: 0.0519 (best-model)
# epoch:24, valid loss: 0.0516 (best-model)
# epoch:25, valid loss: 0.0514 (best-model)
# epoch:26, valid loss: 0.0514 (best-model)
# epoch:27, valid loss: 0.0512 (best-model)
# epoch:28, valid loss: 0.0506 (best-model)
# epoch:29, valid loss: 0.0516
# epoch:30, valid loss: 0.0508
# epoch:31, valid loss: 0.0504 (best-model)
# epoch:32, valid loss: 0.0506
# epoch:33, valid loss: 0.0506
# epoch:34, valid loss: 0.0504 (best-model)
# epoch:35, valid loss: 0.0494 (best-model)
# epoch:36, valid loss: 0.0494 (best-model)
# epoch:37, valid loss: 0.0492 (best-model)
# epoch:38, valid loss: 0.0502
# epoch:39, valid loss: 0.0496
# epoch:40, valid loss: 0.0487 (best-model)
# epoch:41, valid loss: 0.0485 (best-model)
# epoch:42, valid loss: 0.0483 (best-model)
# epoch:43, valid loss: 0.0480 (best-model)
# epoch:44, valid loss: 0.0478 (best-model)
# epoch:45, valid loss: 0.0482
# epoch:46, valid loss: 0.0476 (best-model)
# epoch:47, valid loss: 0.0473 (best-model)
# epoch:48, valid loss: 0.0468 (best-model)
# epoch:49, valid loss: 0.0471
# epoch:50, valid loss: 0.0469
# epoch:51, valid loss: 0.0461 (best-model)
# epoch:52, valid loss: 0.0467
# epoch:53, valid loss: 0.0459 (best-model)
# epoch:54, valid loss: 0.0467
# epoch:55, valid loss: 0.0461
# epoch:56, valid loss: 0.0463
# epoch:57, valid loss: 0.0461
# epoch:58, valid loss: 0.0471
# epoch:59, valid loss: 0.0469
# epoch:60, valid loss: 0.0449 (best-model)
# epoch:61, valid loss: 0.0452
# epoch:62, valid loss: 0.0456
# epoch:63, valid loss: 0.0464
# epoch:64, valid loss: 0.0455
# epoch:65, valid loss: 0.0454
# epoch:66, valid loss: 0.0454
# epoch:67, valid loss: 0.0448 (best-model)
# epoch:68, valid loss: 0.0441 (best-model)
# epoch:69, valid loss: 0.0452
# epoch:70, valid loss: 0.0461
# epoch:71, valid loss: 0.0444
# epoch:72, valid loss: 0.0445
# epoch:73, valid loss: 0.0444
# epoch:74, valid loss: 0.0446
# epoch:75, valid loss: 0.0458
# epoch:76, valid loss: 0.0451
# epoch:77, valid loss: 0.0450
# epoch:78, valid loss: 0.0444
# epoch:79, valid loss: 0.0449
# epoch:80, valid loss: 0.0440 (best-model)
# epoch:81, valid loss: 0.0448
# epoch:82, valid loss: 0.0443
# epoch:83, valid loss: 0.0441
# epoch:84, valid loss: 0.0447
# epoch:85, valid loss: 0.0443
# epoch:86, valid loss: 0.0447
# epoch:87, valid loss: 0.0440 (best-model)
# epoch:88, valid loss: 0.0440 (best-model)
# epoch:89, valid loss: 0.0449
# epoch:90, valid loss: 0.0438 (best-model)
# epoch:91, valid loss: 0.0448
# epoch:92, valid loss: 0.0439
# epoch:93, valid loss: 0.0442
# epoch:94, valid loss: 0.0436 (best-model)
# epoch:95, valid loss: 0.0452
# epoch:96, valid loss: 0.0438
# epoch:97, valid loss: 0.0434 (best-model)
# epoch:98, valid loss: 0.0436
# epoch:99, valid loss: 0.0441
# epoch:100, valid loss: 0.0445
# epoch:101, valid loss: 0.0434
# epoch:102, valid loss: 0.0440
# epoch:103, valid loss: 0.0434 (best-model)
# epoch:104, valid loss: 0.0434
# epoch:105, valid loss: 0.0442
# epoch:106, valid loss: 0.0452
# epoch:107, valid loss: 0.0448
# epoch:108, valid loss: 0.0442
# epoch:109, valid loss: 0.0441
# epoch:110, valid loss: 0.0438
# epoch:111, valid loss: 0.0455
# epoch:112, valid loss: 0.0434
# epoch:113, valid loss: 0.0448
# epoch:114, valid loss: 0.0440
# epoch:115, valid loss: 0.0447
# epoch:116, valid loss: 0.0433 (best-model)
# epoch:117, valid loss: 0.0433
# epoch:118, valid loss: 0.0439
# epoch:119, valid loss: 0.0437
# epoch:120, valid loss: 0.0439
# epoch:121, valid loss: 0.0448
# epoch:122, valid loss: 0.0434
# epoch:123, valid loss: 0.0448
# epoch:124, valid loss: 0.0442
# epoch:125, valid loss: 0.0442
# epoch:126, valid loss: 0.0439
# epoch:127, valid loss: 0.0447
# epoch:128, valid loss: 0.0435
# epoch:129, valid loss: 0.0438
# epoch:130, valid loss: 0.0435
# epoch:131, valid loss: 0.0438
# epoch:132, valid loss: 0.0436
# epoch:133, valid loss: 0.0436
# epoch:134, valid loss: 0.0434
# epoch:135, valid loss: 0.0448
# epoch:136, valid loss: 0.0434
# epoch:137, valid loss: 0.0440
# epoch:138, valid loss: 0.0435
# epoch:139, valid loss: 0.0451
# epoch:140, valid loss: 0.0445
# epoch:141, valid loss: 0.0441
# epoch:142, valid loss: 0.0438
# epoch:143, valid loss: 0.0449
# epoch:144, valid loss: 0.0433
# epoch:145, valid loss: 0.0451
# epoch:146, valid loss: 0.0448
# epoch:147, valid loss: 0.0439
# epoch:148, valid loss: 0.0440
# epoch:149, valid loss: 0.0438
# epoch:150, valid loss: 0.0437
# epoch:151, valid loss: 0.0452
# epoch:152, valid loss: 0.0433 (best-model)
# epoch:153, valid loss: 0.0448
# epoch:154, valid loss: 0.0441
# epoch:155, valid loss: 0.0433 (best-model)
# epoch:156, valid loss: 0.0437
# epoch:157, valid loss: 0.0436
# epoch:158, valid loss: 0.0435
# epoch:159, valid loss: 0.0440
# epoch:160, valid loss: 0.0454
# epoch:161, valid loss: 0.0438
# epoch:162, valid loss: 0.0438
# epoch:163, valid loss: 0.0438
# epoch:164, valid loss: 0.0429 (best-model)
# epoch:165, valid loss: 0.0447
# epoch:166, valid loss: 0.0440
# epoch:167, valid loss: 0.0451
# epoch:168, valid loss: 0.0456
# epoch:169, valid loss: 0.0446
# epoch:170, valid loss: 0.0430
# epoch:171, valid loss: 0.0435
# epoch:172, valid loss: 0.0444
# epoch:173, valid loss: 0.0452
# epoch:174, valid loss: 0.0449
# epoch:175, valid loss: 0.0452
# epoch:176, valid loss: 0.0448
# epoch:177, valid loss: 0.0442
# epoch:178, valid loss: 0.0448
# epoch:179, valid loss: 0.0446
# epoch:180, valid loss: 0.0443
# epoch:181, valid loss: 0.0439
# epoch:182, valid loss: 0.0452
# epoch:183, valid loss: 0.0435
# epoch:184, valid loss: 0.0450
# epoch:185, valid loss: 0.0451
# epoch:186, valid loss: 0.0446
# epoch:187, valid loss: 0.0447
# epoch:188, valid loss: 0.0447
# epoch:189, valid loss: 0.0440
# epoch:190, valid loss: 0.0438
# epoch:191, valid loss: 0.0446
# epoch:192, valid loss: 0.0449
# epoch:193, valid loss: 0.0452
# epoch:194, valid loss: 0.0444
# epoch:195, valid loss: 0.0440
# epoch:196, valid loss: 0.0436
# epoch:197, valid loss: 0.0442
# epoch:198, valid loss: 0.0446
# epoch:199, valid loss: 0.0463
# epoch:200, valid loss: 0.0448
# epoch:201, valid loss: 0.0445
# epoch:202, valid loss: 0.0442
# epoch:203, valid loss: 0.0442
# epoch:204, valid loss: 0.0436
# epoch:205, valid loss: 0.0441
# epoch:206, valid loss: 0.0437
# epoch:207, valid loss: 0.0437
# epoch:208, valid loss: 0.0463
# epoch:209, valid loss: 0.0443
# epoch:210, valid loss: 0.0441
# epoch:211, valid loss: 0.0448
# epoch:212, valid loss: 0.0445
# epoch:213, valid loss: 0.0477
# epoch:214, valid loss: 0.0448
# epoch:215, valid loss: 0.0456
# epoch:216, valid loss: 0.0446
# epoch:217, valid loss: 0.0441
# epoch:218, valid loss: 0.0442
# epoch:219, valid loss: 0.0441
# epoch:220, valid loss: 0.0449
# epoch:221, valid loss: 0.0448
# epoch:222, valid loss: 0.0445
# epoch:223, valid loss: 0.0448
# epoch:224, valid loss: 0.0445
# epoch:225, valid loss: 0.0458
# epoch:226, valid loss: 0.0452
# epoch:227, valid loss: 0.0449
# epoch:228, valid loss: 0.0437
# epoch:229, valid loss: 0.0446
# epoch:230, valid loss: 0.0450
# epoch:231, valid loss: 0.0451
# epoch:232, valid loss: 0.0449
# epoch:233, valid loss: 0.0458
# epoch:234, valid loss: 0.0447
# epoch:235, valid loss: 0.0461
# epoch:236, valid loss: 0.0462
# epoch:237, valid loss: 0.0451
# epoch:238, valid loss: 0.0440
# epoch:239, valid loss: 0.0455
# epoch:240, valid loss: 0.0435
# epoch:241, valid loss: 0.0465
# epoch:242, valid loss: 0.0453
# epoch:243, valid loss: 0.0450
# epoch:244, valid loss: 0.0458
# epoch:245, valid loss: 0.0439
# epoch:246, valid loss: 0.0440
# epoch:247, valid loss: 0.0435
# epoch:248, valid loss: 0.0448
# epoch:249, valid loss: 0.0437
# epoch:250, valid loss: 0.0439
# epoch:251, valid loss: 0.0437
# epoch:252, valid loss: 0.0441
# epoch:253, valid loss: 0.0453
# epoch:254, valid loss: 0.0445
# epoch:255, valid loss: 0.0454
# epoch:256, valid loss: 0.0463
# epoch:257, valid loss: 0.0442
# epoch:258, valid loss: 0.0447
# epoch:259, valid loss: 0.0446
# epoch:260, valid loss: 0.0450
# epoch:261, valid loss: 0.0444
# epoch:262, valid loss: 0.0473
# epoch:263, valid loss: 0.0456
# epoch:264, valid loss: 0.0449
# Epoch 00266: reducing learning rate of group 0 to 5.0000e-05.
# epoch:265, valid loss: 0.0459
# epoch:266, valid loss: 0.0437
# epoch:267, valid loss: 0.0452
# epoch:268, valid loss: 0.0442
# epoch:269, valid loss: 0.0451
# epoch:270, valid loss: 0.0453
# epoch:271, valid loss: 0.0445
# epoch:272, valid loss: 0.0454
# epoch:273, valid loss: 0.0446
# epoch:274, valid loss: 0.0444
# epoch:275, valid loss: 0.0451
# epoch:276, valid loss: 0.0446
# epoch:277, valid loss: 0.0445
# epoch:278, valid loss: 0.0438
# epoch:279, valid loss: 0.0449
# epoch:280, valid loss: 0.0447
# epoch:281, valid loss: 0.0448
# epoch:282, valid loss: 0.0446
# epoch:283, valid loss: 0.0443
# epoch:284, valid loss: 0.0450
# epoch:285, valid loss: 0.0454
# epoch:286, valid loss: 0.0445
# epoch:287, valid loss: 0.0446
# epoch:288, valid loss: 0.0445
# epoch:289, valid loss: 0.0444
# epoch:290, valid loss: 0.0447
# epoch:291, valid loss: 0.0442
# epoch:292, valid loss: 0.0445
# epoch:293, valid loss: 0.0448
# epoch:294, valid loss: 0.0442
# epoch:295, valid loss: 0.0459
# epoch:296, valid loss: 0.0451
# epoch:297, valid loss: 0.0446
# epoch:298, valid loss: 0.0446
# epoch:299, valid loss: 0.0445
# Time taken (seconds): 42.6083

# %% [markdown]
# Traccio adesso il grafico delle due loss function in funzione del numero di epoche

# %%
epoche=np.arange(epoch_best_model)

plt.plot(epoche,train_value[:epoch_best_model],label='training')
plt.plot(epoche,valid_value[:epoch_best_model],ls='--',label='validation')
plt.legend()

plt.title("Loss function del training e del validation")
plt.xlabel("epoche")
plt.ylabel("Loss function")
plt.loglog()
# Out:
# []

# %% [markdown]
# Dal grafico possiamo osservare l'andamento della loss function del training e del validation in funzione del numero di epoche. Entrambe le funzioni decrescono, al crescere del numero di epoche. Mentre la loss function del validation raggiunge un plaetau dopo circa 60 epoche, osserviamo che quella del training continua a decrescere. Quando la loss function raggiunge il plateau significa che la riduzione della loss si è stabilizzata e non diminuisce significativamente anche se il modello continua ad essere allenato. Durante le prime fasi dell'addestramento, sia la training loss che la validation loss diminuiscono gradualmente. Successivamente, si osserva che la validation loss diventi maggiore della training loss dopo circa 80 epoche. Quando si verifica un plateau nella validation loss senza un corrispondente plateau nella training loss, potrebbe indicare che il modello sta iniziando ad overfitting sui dati di addestramento. Questo fenomeno può verificarsi quando il modello impara troppo dai dati di addestramento e non è in grado di generalizzare bene sui dati del validation set.

# %% [markdown]
# ### Ottimizzazione degli iperparametri

# %% [markdown]
# I dati degli iperparametri sono stati finora inseriti in modo arbitrario, in questa sezione verranno determinati i valori del learning rate, del numero di epoche, del numero di strati di neuroni e del numero di neuroni per strato che ottimizzano la rete neuronale. Per fare questo viene utilizzata la libreria di python optuna. Nella seguente cella, viene definita una funzione objective(trial) che prende come argomento un oggetto trial di Optuna. All'interno di questa funzione, vengono suggeriti i valori per gli iperparametri da ottimizzare, come il tasso di apprendimento lr, la dimensione degli strati nascosti hidden_size, il numero di epoche epochs, e il numero di layer num_layers. Per il learning rate viene utilizzata una distribuzione loguniforme in quanto può coprire un intervallo molto ampio di valori in modo logaritmico, mentre per gli altri iperparametri viene suggerito un numero intero per degli intervalli scelti come plausibili.
# Successivamente, viene creato il modello della rete neurale come in precedenza con gli iperparametri suggeriti da optuna,
# con la funzione di perdita (MSELoss) e l'ottimizzatore (Adam).Infine è stato creato uno studio di Optuna con la direzione di minimizzare la funzione obiettivo. Viene chiamato study.optimize per eseguire l'ottimizzazione degli iperparametri, specificando il numero di tentativi da eseguire (n_trials). Ogni tentativo corrisponde a un set diverso di iperparametri suggeriti e valutati.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(NeuralNetwork, self).__init__()
        self.hidden_layers = nn.ModuleList([nn.Linear(input_size, hidden_size)])
        self.hidden_layers.extend([nn.Linear(hidden_size, hidden_size) for _ in range(4)])  # 4 hidden layers
        self.output_layer = nn.Linear(hidden_size, 6)
    #La funzione di inoltro viene utilizzata per propagare l'input attraverso il modello e ottenere l'output    
    def forward(self, x):
        for layer in self.hidden_layers:
            x = torch.relu(layer(x))
        x = self.output_layer(x)
        return x

# Definisci la funzione di obiettivo per l'ottimizzazione di Optuna (includo tutto l'algoritmo dentro la funzione obiettivo)
def objective(trial):
    # Iperparametri da ottimizzare
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    hidden_size = trial.suggest_int('hidden_size', 30, 200)
    epochs = trial.suggest_int('epochs', 100, 500)  # Intervallo ragionevole per il numero di epoche
    num_layers = trial.suggest_int('num_layers', 1, 10)  # Intervallo ragionevole per il numero di layer

    # Creazione del modello
    model = NeuralNetwork(input_size=100, hidden_size=hidden_size)
    
    # Definizione della loss function e dell'ottimizzatore
    loss_func = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
    train_loader = create_dataset('train', file_sfrd, file_parameters, batch_size, seed)
    valid_loader = create_dataset('valid', file_sfrd, file_parameters, batch_size, seed)
    # Addestramento del modello
    for epoch in range(epochs):

    # training
        train_loss, points = 0.0, 0 # la variabile points tiene conto della quantità
                                # di dati analizzati ad ogni epoca ed è utile per
                                # calcolare il valor medio della loss function
        model.train()
        for sfrd_train, parameters_train in train_loader:
       # dimensione del batch
            bs = sfrd_train.shape[0]
        # calcolo del valore previsto dalla rete
            parameters_pred  = model(sfrd_train)

        # calcolo della loss function
            loss = loss_func(parameters_pred, parameters_train)
            train_loss = train_loss + (loss.item())*bs # .item() estrae lo scalare dal tensore
            points = points + bs

        # ottimizzazione dei parametri
            optimizer.zero_grad() # azzeramento del gradiente
            loss.backward()       # calcolo del nuovo gradiente
            optimizer.step()      # calcolo dei nuovi parametri usando l'algoritmo di ottimizzazione

    # calcolo del valor medio
        train_loss = train_loss/points
        train_value[epoch] = train_loss

    # validation
        valid_loss, points = 0.0, 0
        model.eval()
        for sfrd_val, parameters_val in valid_loader:
            with torch.no_grad():   # siccome il valore del gradiente non è necessario,
                                # esso non viene calcolato per non occupare memoria
                                # inutilmente

            # dimensione del batch
                bs = sfrd_val.shape[0]

           
            # calcolo del valore previsto dalla rete
                parameters_pred = model(sfrd_val)
            
                valid_loss += (loss_func(parameters_pred, parameters_val).item())*bs
                points     = points + bs

    # calcolo del valor medio
        valid_loss /= points
        valid_value[epoch]=valid_loss

        scheduler.step(valid_loss)

        return valid_loss





study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler())
study.optimize(objective, n_trials=200)

# Ottieni i migliori iperparametri trovati
best_parameters = study.best_params
print("Best parameters:", best_parameters)


best_lr = best_parameters['lr']
best_hidden_size = best_parameters['hidden_size']
best_epochs = best_parameters['epochs']
best_num_layers = best_parameters['num_layers']
# Out:
# [I 2024-03-16 18:10:50,155] A new study created in memory with name: no-name-0fa41bf2-fd05-4251-ba35-357499de7aec
# [I 2024-03-16 18:10:50,584] Trial 0 finished with value: 0.10829640219608942 and parameters: {'lr': 0.0002501669313997962, 'hidden_size': 165, 'epochs': 154, 'num_layers': 10}. Best is trial 0 with value: 0.10829640219608942.
# [I 2024-03-16 18:10:50,951] Trial 1 finished with value: 0.06580110798279444 and parameters: {'lr': 0.0021116948875238096, 'hidden_size': 114, 'epochs': 148, 'num_layers': 2}. Best is trial 1 with value: 0.06580110798279444.
# [I 2024-03-16 18:10:51,354] Trial 2 finished with value: 0.10363187412420909 and parameters: {'lr': 0.00038603371190861434, 'hidden_size': 125, 'epochs': 126, 'num_layers': 4}. Best is trial 1 with value: 0.06580110798279444.
# [I 2024-03-16 18:10:51,763] Trial 3 finished with value: 0.059226592183113096 and parameters: {'lr': 0.00277155663263069, 'hidden_size': 139, 'epochs': 144, 'num_layers': 5}. Best is trial 3 with value: 0.059226592183113096.
# [I 2024-03-16 18:10:52,132] Trial 4 finished with value: 0.0668143954873085 and parameters: {'lr': 0.0030692916120867234, 'hidden_size': 125, 'epochs': 446, 'num_layers': 7}. Best is trial 3 with value: 0.059226592183113096.
# [I 2024-03-16 18:10:52,528] Trial 5 finished with value: 0.2135974504550298 and parameters: {'lr': 0.00012640996884798943, 'hidden_size': 135, 'epochs': 358, 'num_layers': 6}. Best is trial 3 with value: 0.059226592183113096.
# [I 2024-03-16 18:10:52,883] Trial 6 finished with value: 0.24829177697499594 and parameters: {'lr': 0.0002241651056189942, 'hidden_size': 59, 'epochs': 126, 'num_layers': 2}. Best is trial 3 with value: 0.059226592183113096.
# [I 2024-03-16 18:10:53,277] Trial 7 finished with value: 0.1938442877928416 and parameters: {'lr': 0.0001544785025945176, 'hidden_size': 117, 'epochs': 350, 'num_layers': 5}. Best is trial 3 with value: 0.059226592183113096.
# [I 2024-03-16 18:10:53,677] Trial 8 finished with value: 0.0583363701403141 and parameters: {'lr': 0.0033069648960961794, 'hidden_size': 194, 'epochs': 353, 'num_layers': 10}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:54,084] Trial 9 finished with value: 0.0963629549741745 and parameters: {'lr': 0.00028850178067993284, 'hidden_size': 156, 'epochs': 125, 'num_layers': 10}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:54,529] Trial 10 finished with value: 0.0811505631605784 and parameters: {'lr': 0.00662900711249553, 'hidden_size': 195, 'epochs': 261, 'num_layers': 8}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:54,978] Trial 11 finished with value: 0.06866212328275045 and parameters: {'lr': 0.0010195939663650145, 'hidden_size': 199, 'epochs': 261, 'num_layers': 4}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:55,354] Trial 12 finished with value: 0.07883857031663259 and parameters: {'lr': 0.009457631973261969, 'hidden_size': 74, 'epochs': 454, 'num_layers': 8}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:55,758] Trial 13 finished with value: 0.061324082513650256 and parameters: {'lr': 0.00373775531380564, 'hidden_size': 90, 'epochs': 225, 'num_layers': 4}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:56,111] Trial 14 finished with value: 0.14911420742670695 and parameters: {'lr': 0.0014238307870931889, 'hidden_size': 32, 'epochs': 368, 'num_layers': 1}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:56,590] Trial 15 finished with value: 0.08416563093662262 and parameters: {'lr': 0.0005673331112087032, 'hidden_size': 168, 'epochs': 193, 'num_layers': 8}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:57,042] Trial 16 finished with value: 0.06842865586280823 and parameters: {'lr': 0.005040536691833059, 'hidden_size': 180, 'epochs': 309, 'num_layers': 6}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:57,492] Trial 17 finished with value: 0.06304502482215564 and parameters: {'lr': 0.0020927521648795694, 'hidden_size': 152, 'epochs': 498, 'num_layers': 9}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:57,895] Trial 18 finished with value: 0.08375081390142441 and parameters: {'lr': 0.0007913779989801364, 'hidden_size': 94, 'epochs': 304, 'num_layers': 5}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:58,329] Trial 19 finished with value: 0.06634337951739629 and parameters: {'lr': 0.002011601566531804, 'hidden_size': 143, 'epochs': 404, 'num_layers': 3}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:58,813] Trial 20 finished with value: 0.05992953876654307 and parameters: {'lr': 0.0036794020513218517, 'hidden_size': 180, 'epochs': 201, 'num_layers': 7}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:59,282] Trial 21 finished with value: 0.06022189542651177 and parameters: {'lr': 0.0034838294746374126, 'hidden_size': 180, 'epochs': 193, 'num_layers': 7}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:10:59,774] Trial 22 finished with value: 0.06812352731823922 and parameters: {'lr': 0.0057009794760262775, 'hidden_size': 181, 'epochs': 184, 'num_layers': 9}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:00,242] Trial 23 finished with value: 0.06812228133281072 and parameters: {'lr': 0.0014220190082813698, 'hidden_size': 200, 'epochs': 248, 'num_layers': 7}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:00,685] Trial 24 finished with value: 0.08061512837807337 and parameters: {'lr': 0.009066263175181366, 'hidden_size': 168, 'epochs': 218, 'num_layers': 9}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:01,146] Trial 25 finished with value: 0.06819655562440555 and parameters: {'lr': 0.0029430461142504944, 'hidden_size': 182, 'epochs': 286, 'num_layers': 6}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:01,604] Trial 26 finished with value: 0.06061798925201098 and parameters: {'lr': 0.004822744517389768, 'hidden_size': 145, 'epochs': 106, 'num_layers': 5}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:02,071] Trial 27 finished with value: 0.06957037905852 and parameters: {'lr': 0.0015028932994990696, 'hidden_size': 164, 'epochs': 329, 'num_layers': 10}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:02,530] Trial 28 finished with value: 0.0670433301726977 and parameters: {'lr': 0.002443177699925689, 'hidden_size': 188, 'epochs': 401, 'num_layers': 7}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:02,980] Trial 29 finished with value: 0.061314236323038736 and parameters: {'lr': 0.004240313945428485, 'hidden_size': 163, 'epochs': 168, 'num_layers': 10}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:03,384] Trial 30 finished with value: 0.06637089202801387 and parameters: {'lr': 0.006859801722979454, 'hidden_size': 99, 'epochs': 157, 'num_layers': 3}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:03,849] Trial 31 finished with value: 0.05966147576769193 and parameters: {'lr': 0.0032400418410297787, 'hidden_size': 174, 'epochs': 208, 'num_layers': 7}. Best is trial 8 with value: 0.0583363701403141.
# [I 2024-03-16 18:11:04,301] Trial 32 finished with value: 0.05674686590830485 and parameters: {'lr': 0.002605635285487911, 'hidden_size': 173, 'epochs': 219, 'num_layers': 8}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:04,746] Trial 33 finished with value: 0.06918344517548879 and parameters: {'lr': 0.0018198674912561536, 'hidden_size': 170, 'epochs': 239, 'num_layers': 8}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:05,176] Trial 34 finished with value: 0.05845237925648689 and parameters: {'lr': 0.0025134377261157477, 'hidden_size': 131, 'epochs': 141, 'num_layers': 9}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:05,610] Trial 35 finished with value: 0.0819664740562439 and parameters: {'lr': 0.0009496961103741557, 'hidden_size': 132, 'epochs': 100, 'num_layers': 9}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:06,036] Trial 36 finished with value: 0.06342043469349544 and parameters: {'lr': 0.00262787562165576, 'hidden_size': 107, 'epochs': 144, 'num_layers': 10}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:06,481] Trial 37 finished with value: 0.06930116434892018 and parameters: {'lr': 0.001156942866827578, 'hidden_size': 137, 'epochs': 168, 'num_layers': 9}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:06,927] Trial 38 finished with value: 0.08173362086216608 and parameters: {'lr': 0.0007340089532080553, 'hidden_size': 120, 'epochs': 135, 'num_layers': 10}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:07,348] Trial 39 finished with value: 0.06662635485331217 and parameters: {'lr': 0.0017177431503434854, 'hidden_size': 156, 'epochs': 287, 'num_layers': 8}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:07,780] Trial 40 finished with value: 0.06302549585700035 and parameters: {'lr': 0.0024980608978881495, 'hidden_size': 146, 'epochs': 119, 'num_layers': 6}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:08,198] Trial 41 finished with value: 0.06431834528843562 and parameters: {'lr': 0.003365518511582136, 'hidden_size': 124, 'epochs': 166, 'num_layers': 9}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:08,664] Trial 42 finished with value: 0.09540994435548783 and parameters: {'lr': 0.006700737020153906, 'hidden_size': 189, 'epochs': 224, 'num_layers': 8}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:09,104] Trial 43 finished with value: 0.06025227387746175 and parameters: {'lr': 0.002712352871099551, 'hidden_size': 132, 'epochs': 340, 'num_layers': 7}. Best is trial 32 with value: 0.05674686590830485.
# [I 2024-03-16 18:11:09,525] Trial 44 finished with value: 0.05470459217826525 and parameters: {'lr': 0.004543382449960063, 'hidden_size': 111, 'epochs': 145, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:09,948] Trial 45 finished with value: 0.06253505110740662 and parameters: {'lr': 0.00441041045465077, 'hidden_size': 108, 'epochs': 376, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:10,359] Trial 46 finished with value: 0.06301458984613419 and parameters: {'lr': 0.00783734724286307, 'hidden_size': 112, 'epochs': 137, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:10,779] Trial 47 finished with value: 0.05820454552769661 and parameters: {'lr': 0.005750611016652578, 'hidden_size': 84, 'epochs': 114, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:11,153] Trial 48 finished with value: 0.06306776642799378 and parameters: {'lr': 0.006299673008209285, 'hidden_size': 80, 'epochs': 117, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:11,540] Trial 49 finished with value: 0.06155948271354039 and parameters: {'lr': 0.005002087325647561, 'hidden_size': 64, 'epochs': 185, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:11,920] Trial 50 finished with value: 0.06861476471026738 and parameters: {'lr': 0.0039571466948559895, 'hidden_size': 52, 'epochs': 157, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:12,337] Trial 51 finished with value: 0.06084876994291941 and parameters: {'lr': 0.005533244931329646, 'hidden_size': 79, 'epochs': 144, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:12,762] Trial 52 finished with value: 0.06276032348473867 and parameters: {'lr': 0.0020643127761225464, 'hidden_size': 92, 'epochs': 112, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:13,163] Trial 53 finished with value: 0.0888994421561559 and parameters: {'lr': 0.007992016795638398, 'hidden_size': 117, 'epochs': 128, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:13,640] Trial 54 finished with value: 0.097857013742129 and parameters: {'lr': 0.00040145585301827933, 'hidden_size': 193, 'epochs': 171, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:13,994] Trial 55 finished with value: 0.0803722706437111 and parameters: {'lr': 0.0022469074972288777, 'hidden_size': 42, 'epochs': 180, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:14,414] Trial 56 finished with value: 0.0601395966609319 and parameters: {'lr': 0.003198777101840866, 'hidden_size': 99, 'epochs': 148, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:14,872] Trial 57 finished with value: 0.14338160753250123 and parameters: {'lr': 0.0001684771776747756, 'hidden_size': 156, 'epochs': 389, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:15,285] Trial 58 finished with value: 0.06784466654062271 and parameters: {'lr': 0.00449810373198607, 'hidden_size': 128, 'epochs': 207, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:15,706] Trial 59 finished with value: 0.07919957200686137 and parameters: {'lr': 0.0016417257601945802, 'hidden_size': 141, 'epochs': 316, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:16,119] Trial 60 finished with value: 0.08513522704442342 and parameters: {'lr': 0.0011567261236735615, 'hidden_size': 85, 'epochs': 130, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:16,606] Trial 61 finished with value: 0.05830380951364835 and parameters: {'lr': 0.00313647937694732, 'hidden_size': 172, 'epochs': 422, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:17,050] Trial 62 finished with value: 0.05897085020939509 and parameters: {'lr': 0.0028635650453039466, 'hidden_size': 151, 'epochs': 407, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:17,509] Trial 63 finished with value: 0.06265771826108296 and parameters: {'lr': 0.002951283842433108, 'hidden_size': 150, 'epochs': 434, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:18,004] Trial 64 finished with value: 0.06676819165547689 and parameters: {'lr': 0.003854211198487596, 'hidden_size': 172, 'epochs': 461, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:18,467] Trial 65 finished with value: 0.07990897168715795 and parameters: {'lr': 0.005353810613780046, 'hidden_size': 186, 'epochs': 417, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:18,945] Trial 66 finished with value: 0.06197326724727949 and parameters: {'lr': 0.0036940318007724093, 'hidden_size': 159, 'epochs': 473, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# Epoch 00367: reducing learning rate of group 0 to 2.5000e-05.
# [I 2024-03-16 18:11:19,429] Trial 67 finished with value: 0.06616034343838692 and parameters: {'lr': 0.00227897436910649, 'hidden_size': 174, 'epochs': 443, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:19,881] Trial 68 finished with value: 0.06906102438767751 and parameters: {'lr': 0.0018749977323398001, 'hidden_size': 150, 'epochs': 419, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:20,334] Trial 69 finished with value: 0.06872495919466019 and parameters: {'lr': 0.0028119396579759782, 'hidden_size': 196, 'epochs': 368, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:20,821] Trial 70 finished with value: 0.07432189176479975 and parameters: {'lr': 0.006025031623470018, 'hidden_size': 177, 'epochs': 344, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:21,282] Trial 71 finished with value: 0.059751353561878204 and parameters: {'lr': 0.00426543551229642, 'hidden_size': 136, 'epochs': 424, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:21,758] Trial 72 finished with value: 0.05938745180765788 and parameters: {'lr': 0.0031923770082255476, 'hidden_size': 165, 'epochs': 398, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:22,167] Trial 73 finished with value: 0.0697327733039856 and parameters: {'lr': 0.0024762248559588532, 'hidden_size': 68, 'epochs': 358, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:22,631] Trial 74 finished with value: 0.05789590299129486 and parameters: {'lr': 0.0035505051915974166, 'hidden_size': 160, 'epochs': 292, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:23,111] Trial 75 finished with value: 0.058284959395726525 and parameters: {'lr': 0.004939807615798465, 'hidden_size': 159, 'epochs': 257, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:23,579] Trial 76 finished with value: 0.07131709133585294 and parameters: {'lr': 0.007234697732959768, 'hidden_size': 159, 'epochs': 268, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:24,051] Trial 77 finished with value: 0.06366453051567078 and parameters: {'lr': 0.009681971317015908, 'hidden_size': 183, 'epochs': 293, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:24,535] Trial 78 finished with value: 0.06990301012992858 and parameters: {'lr': 0.00514773199533022, 'hidden_size': 168, 'epochs': 271, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:25,040] Trial 79 finished with value: 0.06595125913619995 and parameters: {'lr': 0.004779463406632736, 'hidden_size': 161, 'epochs': 249, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:25,525] Trial 80 finished with value: 0.05892458632588386 and parameters: {'lr': 0.004109840139346852, 'hidden_size': 190, 'epochs': 280, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:25,990] Trial 81 finished with value: 0.06866990208625794 and parameters: {'lr': 0.0035381001304207976, 'hidden_size': 200, 'epochs': 280, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:26,451] Trial 82 finished with value: 0.060036228398482 and parameters: {'lr': 0.004062644694450193, 'hidden_size': 192, 'epochs': 313, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:26,915] Trial 83 finished with value: 0.06644254763921102 and parameters: {'lr': 0.00842656316089016, 'hidden_size': 176, 'epochs': 255, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:27,388] Trial 84 finished with value: 0.06597603887319564 and parameters: {'lr': 0.005740697217457372, 'hidden_size': 185, 'epochs': 236, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:27,781] Trial 85 finished with value: 0.05949885308742523 and parameters: {'lr': 0.003482253295785193, 'hidden_size': 103, 'epochs': 300, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:28,257] Trial 86 finished with value: 0.061912967960039776 and parameters: {'lr': 0.004317020144610269, 'hidden_size': 189, 'epochs': 332, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:28,750] Trial 87 finished with value: 0.06801413704951605 and parameters: {'lr': 0.004921908201194197, 'hidden_size': 196, 'epochs': 235, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:29,244] Trial 88 finished with value: 0.0791328035791715 and parameters: {'lr': 0.006573027373207814, 'hidden_size': 179, 'epochs': 271, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:29,726] Trial 89 finished with value: 0.06374695549408595 and parameters: {'lr': 0.002289893537600117, 'hidden_size': 166, 'epochs': 282, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:30,189] Trial 90 finished with value: 0.05757807408769926 and parameters: {'lr': 0.0031135697699968103, 'hidden_size': 121, 'epochs': 323, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:30,639] Trial 91 finished with value: 0.06261857012907664 and parameters: {'lr': 0.0031357625482164096, 'hidden_size': 121, 'epochs': 315, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:31,100] Trial 92 finished with value: 0.06068007975816727 and parameters: {'lr': 0.003839001314828993, 'hidden_size': 146, 'epochs': 327, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:31,531] Trial 93 finished with value: 0.07717808524767558 and parameters: {'lr': 0.0026092755806902852, 'hidden_size': 131, 'epochs': 263, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:31,969] Trial 94 finished with value: 0.06274390290180842 and parameters: {'lr': 0.0035262737150166096, 'hidden_size': 127, 'epochs': 302, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:32,400] Trial 95 finished with value: 0.05720724632342657 and parameters: {'lr': 0.00467625147840885, 'hidden_size': 110, 'epochs': 295, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:32,845] Trial 96 finished with value: 0.07273250003655751 and parameters: {'lr': 0.007179655319269027, 'hidden_size': 111, 'epochs': 101, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:33,276] Trial 97 finished with value: 0.07119166553020477 and parameters: {'lr': 0.004553858891606901, 'hidden_size': 101, 'epochs': 294, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:33,685] Trial 98 finished with value: 0.09160995264848074 and parameters: {'lr': 0.006023401548509803, 'hidden_size': 115, 'epochs': 118, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:34,096] Trial 99 finished with value: 0.06521729414661726 and parameters: {'lr': 0.0019235821066029889, 'hidden_size': 107, 'epochs': 322, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:34,530] Trial 100 finished with value: 0.06761120239893595 and parameters: {'lr': 0.002974650037217725, 'hidden_size': 95, 'epochs': 193, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:34,963] Trial 101 finished with value: 0.0623668942352136 and parameters: {'lr': 0.005412428178207397, 'hidden_size': 119, 'epochs': 278, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:35,453] Trial 102 finished with value: 0.06233796258767446 and parameters: {'lr': 0.0037926022573600195, 'hidden_size': 171, 'epochs': 306, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:35,934] Trial 103 finished with value: 0.06566358248392741 and parameters: {'lr': 0.004045961471230353, 'hidden_size': 193, 'epochs': 291, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:36,363] Trial 104 finished with value: 0.07251101305087407 and parameters: {'lr': 0.004648028793935924, 'hidden_size': 53, 'epochs': 154, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:36,805] Trial 105 finished with value: 0.05830016901095708 and parameters: {'lr': 0.003363213911778242, 'hidden_size': 124, 'epochs': 219, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:37,260] Trial 106 finished with value: 0.058026270419359205 and parameters: {'lr': 0.003233360621978898, 'hidden_size': 124, 'epochs': 216, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:37,708] Trial 107 finished with value: 0.060745049913724265 and parameters: {'lr': 0.003225674164609764, 'hidden_size': 123, 'epochs': 215, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:38,117] Trial 108 finished with value: 0.06256403793891271 and parameters: {'lr': 0.002751454379082913, 'hidden_size': 86, 'epochs': 223, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:38,558] Trial 109 finished with value: 0.06163541158040364 and parameters: {'lr': 0.002226296560559665, 'hidden_size': 142, 'epochs': 199, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:38,975] Trial 110 finished with value: 0.10177317331234614 and parameters: {'lr': 0.0005186367882409817, 'hidden_size': 112, 'epochs': 244, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:39,429] Trial 111 finished with value: 0.05765680283308029 and parameters: {'lr': 0.0033793871434635533, 'hidden_size': 130, 'epochs': 490, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:39,902] Trial 112 finished with value: 0.07290283938248952 and parameters: {'lr': 0.0033509561991597213, 'hidden_size': 127, 'epochs': 499, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:40,339] Trial 113 finished with value: 0.059606902201970416 and parameters: {'lr': 0.0029447345623766006, 'hidden_size': 117, 'epochs': 470, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:40,805] Trial 114 finished with value: 0.06289720406134923 and parameters: {'lr': 0.004920950258143906, 'hidden_size': 139, 'epochs': 212, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:41,268] Trial 115 finished with value: 0.05782696902751923 and parameters: {'lr': 0.003671418539721604, 'hidden_size': 123, 'epochs': 228, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:41,708] Trial 116 finished with value: 0.06590330799420675 and parameters: {'lr': 0.003514917280719812, 'hidden_size': 105, 'epochs': 253, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:42,124] Trial 117 finished with value: 0.06172992433110873 and parameters: {'lr': 0.004394378734785986, 'hidden_size': 122, 'epochs': 489, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:42,580] Trial 118 finished with value: 0.06435676376024882 and parameters: {'lr': 0.005727345941328307, 'hidden_size': 135, 'epochs': 227, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:43,014] Trial 119 finished with value: 0.066119650999705 and parameters: {'lr': 0.002472237388958977, 'hidden_size': 110, 'epochs': 180, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:43,471] Trial 120 finished with value: 0.06250813762346903 and parameters: {'lr': 0.0038079272864468853, 'hidden_size': 129, 'epochs': 228, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:43,927] Trial 121 finished with value: 0.18250042021274568 and parameters: {'lr': 0.00010985126545063248, 'hidden_size': 156, 'epochs': 379, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:44,351] Trial 122 finished with value: 0.06097942759593328 and parameters: {'lr': 0.003135111148203474, 'hidden_size': 115, 'epochs': 201, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:44,814] Trial 123 finished with value: 0.06805799136559168 and parameters: {'lr': 0.0027318255408336593, 'hidden_size': 126, 'epochs': 338, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:45,249] Trial 124 finished with value: 0.06902261803547541 and parameters: {'lr': 0.0052857908983475815, 'hidden_size': 118, 'epochs': 241, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:45,698] Trial 125 finished with value: 0.06677250762780508 and parameters: {'lr': 0.004000240083409309, 'hidden_size': 123, 'epochs': 352, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:46,189] Trial 126 finished with value: 0.07079908654093742 and parameters: {'lr': 0.0034672938769633216, 'hidden_size': 162, 'epochs': 260, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:46,646] Trial 127 finished with value: 0.05852072477340698 and parameters: {'lr': 0.004572864842798881, 'hidden_size': 135, 'epochs': 207, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:47,085] Trial 128 finished with value: 0.06692994907498359 and parameters: {'lr': 0.002921353017991738, 'hidden_size': 75, 'epochs': 233, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:47,506] Trial 129 finished with value: 0.07211891641219458 and parameters: {'lr': 0.002087133806417737, 'hidden_size': 96, 'epochs': 449, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:47,974] Trial 130 finished with value: 0.05853221947948138 and parameters: {'lr': 0.0041807134919896495, 'hidden_size': 131, 'epochs': 490, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:48,436] Trial 131 finished with value: 0.06175504813591639 and parameters: {'lr': 0.002608342646436529, 'hidden_size': 133, 'epochs': 125, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:48,883] Trial 132 finished with value: 0.060413176814715065 and parameters: {'lr': 0.002400491502167055, 'hidden_size': 124, 'epochs': 140, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:49,290] Trial 133 finished with value: 0.07110655546188355 and parameters: {'lr': 0.003287669346734135, 'hidden_size': 138, 'epochs': 219, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:49,767] Trial 134 finished with value: 0.06274308572212856 and parameters: {'lr': 0.0036527858194049206, 'hidden_size': 144, 'epochs': 161, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:50,192] Trial 135 finished with value: 0.13921180089314777 and parameters: {'lr': 0.0002424633805411285, 'hidden_size': 114, 'epochs': 111, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:50,660] Trial 136 finished with value: 0.07867351164420446 and parameters: {'lr': 0.006179185106647526, 'hidden_size': 152, 'epochs': 176, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:51,127] Trial 137 finished with value: 0.057765808055798215 and parameters: {'lr': 0.0030589185013223026, 'hidden_size': 130, 'epochs': 362, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:51,564] Trial 138 finished with value: 0.0649117574095726 and parameters: {'lr': 0.0030776659289633505, 'hidden_size': 120, 'epochs': 359, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:52,072] Trial 139 finished with value: 0.06019429395596186 and parameters: {'lr': 0.005047336392186768, 'hidden_size': 167, 'epochs': 320, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:52,512] Trial 140 finished with value: 0.061276178310314816 and parameters: {'lr': 0.0037691202984275244, 'hidden_size': 89, 'epochs': 392, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:52,962] Trial 141 finished with value: 0.05741304486989975 and parameters: {'lr': 0.00286185052589273, 'hidden_size': 128, 'epochs': 378, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:53,388] Trial 142 finished with value: 0.06607021644711494 and parameters: {'lr': 0.002770172010081047, 'hidden_size': 128, 'epochs': 364, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:53,837] Trial 143 finished with value: 0.05901761665940285 and parameters: {'lr': 0.0033407931364042957, 'hidden_size': 124, 'epochs': 342, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:54,245] Trial 144 finished with value: 0.06632738282283147 and parameters: {'lr': 0.004221908981308364, 'hidden_size': 130, 'epochs': 409, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:54,702] Trial 145 finished with value: 0.06339176386594772 and parameters: {'lr': 0.0035828908796179428, 'hidden_size': 148, 'epochs': 371, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:55,118] Trial 146 finished with value: 0.0657835794488589 and parameters: {'lr': 0.0029725272411883063, 'hidden_size': 109, 'epochs': 384, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:55,577] Trial 147 finished with value: 0.06455244670311609 and parameters: {'lr': 0.00460455352976883, 'hidden_size': 116, 'epochs': 352, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:56,005] Trial 148 finished with value: 0.06540274322032928 and parameters: {'lr': 0.002624438177416027, 'hidden_size': 119, 'epochs': 329, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:56,476] Trial 149 finished with value: 0.05983619630336762 and parameters: {'lr': 0.003986291774092703, 'hidden_size': 140, 'epochs': 433, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:56,976] Trial 150 finished with value: 0.06728252033392589 and parameters: {'lr': 0.001643605720350053, 'hidden_size': 177, 'epochs': 305, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:57,422] Trial 151 finished with value: 0.05640678862730662 and parameters: {'lr': 0.0031561861587011287, 'hidden_size': 132, 'epochs': 190, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:57,893] Trial 152 finished with value: 0.06212598323822022 and parameters: {'lr': 0.0032770832455176, 'hidden_size': 135, 'epochs': 214, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:58,293] Trial 153 finished with value: 0.0735443448026975 and parameters: {'lr': 0.0030642916130803497, 'hidden_size': 31, 'epochs': 192, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:58,732] Trial 154 finished with value: 0.06245399703582128 and parameters: {'lr': 0.0037058812211830266, 'hidden_size': 128, 'epochs': 230, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:59,160] Trial 155 finished with value: 0.06222196330626806 and parameters: {'lr': 0.002377766956008588, 'hidden_size': 125, 'epochs': 187, 'num_layers': 1}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:11:59,617] Trial 156 finished with value: 0.06346524049838384 and parameters: {'lr': 0.002844744710669205, 'hidden_size': 133, 'epochs': 204, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:00,118] Trial 157 finished with value: 0.06116144140561422 and parameters: {'lr': 0.00432137969765211, 'hidden_size': 172, 'epochs': 247, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:00,582] Trial 158 finished with value: 0.06445820053418477 and parameters: {'lr': 0.003428151077368538, 'hidden_size': 105, 'epochs': 375, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:01,063] Trial 159 finished with value: 0.06627110540866851 and parameters: {'lr': 0.004830977942802498, 'hidden_size': 113, 'epochs': 345, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:01,553] Trial 160 finished with value: 0.0740029608209928 and parameters: {'lr': 0.005579948754798227, 'hidden_size': 159, 'epochs': 295, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:02,011] Trial 161 finished with value: 0.05963296403487523 and parameters: {'lr': 0.002185552613119632, 'hidden_size': 120, 'epochs': 135, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:02,454] Trial 162 finished with value: 0.06224400242169698 and parameters: {'lr': 0.002487758358252348, 'hidden_size': 132, 'epochs': 222, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:02,932] Trial 163 finished with value: 0.058240389128526054 and parameters: {'lr': 0.0030962670375182695, 'hidden_size': 127, 'epochs': 147, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:03,379] Trial 164 finished with value: 0.06431521862745285 and parameters: {'lr': 0.0032448758689976147, 'hidden_size': 126, 'epochs': 167, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:03,846] Trial 165 finished with value: 0.06097353587547938 and parameters: {'lr': 0.003913282735574625, 'hidden_size': 184, 'epochs': 145, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:04,322] Trial 166 finished with value: 0.06052765150864919 and parameters: {'lr': 0.0027478011531190207, 'hidden_size': 154, 'epochs': 335, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:04,763] Trial 167 finished with value: 0.06762819300095241 and parameters: {'lr': 0.0031063064818922506, 'hidden_size': 123, 'epochs': 461, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# Epoch 00468: reducing learning rate of group 0 to 1.2500e-05.
# [I 2024-03-16 18:12:05,190] Trial 168 finished with value: 0.06069449548919996 and parameters: {'lr': 0.003573946203904813, 'hidden_size': 128, 'epochs': 236, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:05,658] Trial 169 finished with value: 0.059174606005350745 and parameters: {'lr': 0.004177968091394989, 'hidden_size': 137, 'epochs': 152, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:06,108] Trial 170 finished with value: 0.06325343817472458 and parameters: {'lr': 0.00295380196070306, 'hidden_size': 120, 'epochs': 363, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:06,584] Trial 171 finished with value: 0.06594801823298137 and parameters: {'lr': 0.0025619533326493578, 'hidden_size': 132, 'epochs': 129, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:07,035] Trial 172 finished with value: 0.058396067023277286 and parameters: {'lr': 0.0033448688128518817, 'hidden_size': 130, 'epochs': 118, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:07,500] Trial 173 finished with value: 0.06576354955633482 and parameters: {'lr': 0.0033879529958568324, 'hidden_size': 126, 'epochs': 117, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:07,955] Trial 174 finished with value: 0.06031919926404953 and parameters: {'lr': 0.003769104081742516, 'hidden_size': 122, 'epochs': 107, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:08,376] Trial 175 finished with value: 0.06537066092093785 and parameters: {'lr': 0.0031176777515239612, 'hidden_size': 64, 'epochs': 100, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:08,845] Trial 176 finished with value: 0.06360282341639201 and parameters: {'lr': 0.0028034858758570376, 'hidden_size': 142, 'epochs': 123, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:09,292] Trial 177 finished with value: 0.0623240993420283 and parameters: {'lr': 0.004546637548844396, 'hidden_size': 130, 'epochs': 215, 'num_layers': 4}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:09,725] Trial 178 finished with value: 0.06595340132713318 and parameters: {'lr': 0.0035304059415592437, 'hidden_size': 115, 'epochs': 198, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:10,135] Trial 179 finished with value: 0.15092194557189942 and parameters: {'lr': 0.0003288944395017794, 'hidden_size': 36, 'epochs': 275, 'num_layers': 5}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:10,560] Trial 180 finished with value: 0.05861513753732046 and parameters: {'lr': 0.005180924319984212, 'hidden_size': 119, 'epochs': 311, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:11,008] Trial 181 finished with value: 0.06316655884186427 and parameters: {'lr': 0.002610764652546848, 'hidden_size': 134, 'epochs': 141, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:11,457] Trial 182 finished with value: 0.06385112583637237 and parameters: {'lr': 0.003070499993542283, 'hidden_size': 138, 'epochs': 158, 'num_layers': 9}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:11,912] Trial 183 finished with value: 0.06531032542387645 and parameters: {'lr': 0.0038963477547911884, 'hidden_size': 130, 'epochs': 128, 'num_layers': 8}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:12,374] Trial 184 finished with value: 0.0580116069316864 and parameters: {'lr': 0.003341237466549759, 'hidden_size': 125, 'epochs': 137, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:12,836] Trial 185 finished with value: 0.07381285081307093 and parameters: {'lr': 0.003328294699485385, 'hidden_size': 125, 'epochs': 135, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:13,300] Trial 186 finished with value: 0.06870822444558143 and parameters: {'lr': 0.001275161774495866, 'hidden_size': 163, 'epochs': 118, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:13,717] Trial 187 finished with value: 0.07998309085766474 and parameters: {'lr': 0.000795589740043154, 'hidden_size': 122, 'epochs': 286, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:14,142] Trial 188 finished with value: 0.06462697351972262 and parameters: {'lr': 0.0028720583356321326, 'hidden_size': 127, 'epochs': 258, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:14,589] Trial 189 finished with value: 0.06752267668644588 and parameters: {'lr': 0.0036560793070716303, 'hidden_size': 113, 'epochs': 396, 'num_layers': 6}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:15,014] Trial 190 finished with value: 0.061622146517038345 and parameters: {'lr': 0.004190775375619443, 'hidden_size': 117, 'epochs': 112, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:15,453] Trial 191 finished with value: 0.05683053880929947 and parameters: {'lr': 0.0032584270664017937, 'hidden_size': 130, 'epochs': 149, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:15,929] Trial 192 finished with value: 0.06154813632369041 and parameters: {'lr': 0.0033362408018990817, 'hidden_size': 130, 'epochs': 146, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:16,391] Trial 193 finished with value: 0.17201769848664603 and parameters: {'lr': 0.00018418171481100705, 'hidden_size': 124, 'epochs': 209, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:16,860] Trial 194 finished with value: 0.06791096558173497 and parameters: {'lr': 0.0032345137076128273, 'hidden_size': 133, 'epochs': 383, 'num_layers': 10}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:17,289] Trial 195 finished with value: 0.06254411667585373 and parameters: {'lr': 0.002953689566989948, 'hidden_size': 81, 'epochs': 150, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:17,749] Trial 196 finished with value: 0.059072074890136717 and parameters: {'lr': 0.00369243047453602, 'hidden_size': 127, 'epochs': 130, 'num_layers': 7}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:18,248] Trial 197 finished with value: 0.06563618888457616 and parameters: {'lr': 0.0027183620557668354, 'hidden_size': 170, 'epochs': 161, 'num_layers': 2}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:18,758] Trial 198 finished with value: 0.0563615349928538 and parameters: {'lr': 0.004105088607737879, 'hidden_size': 174, 'epochs': 266, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# [I 2024-03-16 18:12:19,278] Trial 199 finished with value: 0.06649005115032196 and parameters: {'lr': 0.004418744547766538, 'hidden_size': 178, 'epochs': 176, 'num_layers': 3}. Best is trial 44 with value: 0.05470459217826525.
# Best parameters: {'lr': 0.004543382449960063, 'hidden_size': 111, 'epochs': 145, 'num_layers': 5}

# %% [markdown]
#  E' stato creato un file csv per visualizzare tutte le combinazioni degli iperparametri con i relativi trials

# %%
# Ottieni un DataFrame con le informazioni sui trial
trials_df = study.trials_dataframe()

# Salva il DataFrame come file CSV
trials_df.to_csv('parametri_trials.csv', index=False)

# %% [markdown]
# ### Confronto tra i valori predetti dalla rete neuronale con quelli veri per il test set.

# %% [markdown]
# Nella prossima cella viene eseguito il test finale del modello allenato sul set di dati di test. Analogagamente a quanto fatto prima, viene utilizzata la funzione create_dataset per creare un DataLoader per il set di dati di test utilizzando i file di dati file_sfrd e file_parameters con un determinato batch_size e seed. Vengono eseguite iterazioni attraverso il DataLoader per il set di dati di test. Durante ogni iterazione, il modello viene utilizzato per fare previsioni sui dati di input (sfrd_test) e i risultati vengono confrontati con i valori di output attesi (parameters_test). I valori previsti e i valori reali dei parametri vengono salvati in array numpy (parameters_NN e parameters_true). Infine, viene calcolata  anche la loss function utilizzando i valori predetti e quelli reali e la loss totale viene divisa per il numero totale di punti nel set di dati di test per ottenere la loss media.

# %%
test_loader = create_dataset('test', file_sfrd, file_parameters, batch_size, seed) #test dataset



# test
sfrd_values=np.zeros((int(sfrd_data.shape[0]*0.15),100), dtype=np.float32)
parameters_true = np.zeros((int(parameters_data.shape[0]*0.15),6), dtype=np.float32)
parameters_NN = np.zeros((int(parameters_data.shape[0]*0.15),6), dtype=np.float32)

offset = 0
test_loss, points = 0.0, 0
model.eval()

counter=0

for sfrd_test, parameters_test in test_loader:
    with torch.no_grad():

        bs = sfrd_test.shape[0]

        

        # calcolo dei valori previsti dalla rete
        parameters_pred = model(sfrd_test)

        # memorizzazione dei valori reali e calcolati dei parametri
        # spostamento dei dati alla CPU e traduzione in array Numpy

        sfrd_values[counter:counter+bs,:]=sfrd_test.numpy()
        parameters_true[counter:counter+bs,:]= parameters_test.numpy()
        parameters_NN[counter:counter+bs,:]= parameters_pred.numpy()

        test_loss += (loss_func(parameters_pred, parameters_test).item())*sfrd_test.shape[0]
        points += sfrd_test.shape[0]

        counter += bs

# calcolo del valore medio
test_loss /= points

print('test loss = %.3e'%test_loss)
# Out:
# test loss = 4.933e-02

# %% [markdown]
# Costruisco una griglia contenente 6 grafici ognuno relativo ad ogni parametro in cui nelle ascisse di ogni grafico sono presenti i valori veri dei parametri e in ordinata i valori predetti dalla rete. Questi subplot sono organizzati in una griglia 3x2.Per ciascun parametro, viene eseguito un grafico a dispersione (plt.scatter) con i valori reali (parameters_true[:, j]) sull'asse x e i valori predetti (parameters_NN[:, j]) sull'asse y. Successivamente, è stata tracciata una linea di riferimento che rappresenta una stima perfetta in cui i valori reali e quelli predetti coincidono. Se tutti i punti dello scatter appartenessero alla linea allora la predizione della rete neurale sarebbe perfetta, ossia il modello costruito rispetta esattamente i valori dei parametri reali.

# %%
# produzione del  grafico
label = [r'$\Omega_{m}$',r'$\sigma_{8}$',r'$A_{SN1}$',r'$A_{SN2}$',r'$A_{AGN1}$',r'$A_{AGN2}$' ]
plt.figure(figsize=(9, 9))
# genero numeri con distribuzione uniforme
u= np.random.uniform(0, 1, 1000)
#ciclo per creare griglia per ogni parametro
for j in range(6):
    plt.subplot(3, 2, j + 1)
    plt.scatter(parameters_true[:, j], parameters_NN[:, j], s = 3, color='green',alpha=0.6, marker='o')
    #eq retta y=x 
    plt.plot(u, u, color='black') 
    plt.title(label[j])
    plt.xlabel('Parametri reali')
    plt.ylabel('Stime NN')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dai grafici possiamo osservare andamenti diversi dello scatter per i vari parametri. Sembra che per i parametri $A_{SN1}$ e $A_{AGN1}$ il modello costruito si avvicini molto ai valori reali. Un andamento meno sperato si visualizza per i parametri $A_{SN2}$ e $A_{AGN2}$ in cui i valori dei puntini riempono tutto il grafico (il primo con maggiore concentrazione verso numeri vicini allo 0, il secondo riempie indistintamente tutto il grafico). Per i parametri cosmologici non è semplice fare un confronto dalla semplice osservazione del grafico

# %% [markdown]
# Per avere un'idea più quantitativa viene costruita una rete neurale che predice anche gli erorri oltre che i valori dei parametri

# %% [markdown]
# ### Stima dell'errore sui parametri

# %% [markdown]
# In questa sezione verrà riapplicato lo stesso algoritmo utilizzato precedentemente, con una loss function che non è più Mean Square Error, ma tiene conto di un termine aggiuntivo dovuto all'errore $$L(\vec{\theta}) = log \sum_{i} (\vec{\theta}_i-\hat{\vec{\theta}}_i)^2 + \log \sum_{i} (\vec{\theta}_i^2 - \vec{\sigma_i}^2)^2$$
# Questa volta nella rete neurale costruita non ci saranno più 6 valori di output ma 12 perchè ad ogni parametro è associato il proprio errore

# %%
seed           = 1
min_valid_loss = 1e7                       
batch_size     = 32                        # numero di elementi per ciascun batch
lr             = 0.0002                      # learning rate
wd             = 0.0                       # weight decay
dr             = 0.1                       # dropout rate
epochs         = 130                       # numero di iterazioni (epoche)
hidden_size    = 89
patience       = 100
stop_criterion = 200
f_model        = 'best_model.pt'

# %%
model = nn.Sequential(
            nn.Linear(100, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 12)) #in output ci sono i 6 parametri e i relativi errori


# creazione dei dataset
train_loader = create_dataset('train', file_sfrd, file_parameters, batch_size, seed) #training dataset
valid_loader = create_dataset('valid', file_sfrd, file_parameters, batch_size, seed) #validation dataset

# %% [markdown]
# Ecco la classe in cui viene definita la nuova loss function

# %%
class loss_function(nn.Module):
    def __init__(self):
        super(loss_function, self).__init__()
    def forward(self, parameters_error_pred, parameters_train):
        num_parameters = parameters_error_pred.shape[1] // 2
        loss=0.0
      #   si assume che parametri e rispettivi errori si alternino
        for i in range(num_parameters):
            loss += torch.log(torch.sum((parameters_train[:,i] - parameters_error_pred[:,2*i])**2)) + torch.log(torch.sum(((parameters_train[:,i]-parameters_error_pred[:,2*i])**2. - parameters_error_pred[:,2*i+1]**2.)**2.))
          
        return loss

# definizione di loss function e ottimizzatore
loss_func = loss_function()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=(0.5, 0.999), weight_decay=wd)

# %%
start = time.time() # accensione cronometro

train_value=np.zeros(epochs)
valid_value=np.zeros(epochs)

min_valid_loss_param=min_valid_loss

scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=patience,
                                           min_lr= 1.0e-6, verbose=True)

epoch_best_model = 0

for epoch in range(epochs):

    # training
    train_loss, points = 0.0, 0
    model.train()
    for sfrd_train, parameters_train in train_loader:

         # dimensione del batch
        bs = sfrd_train.shape[0]

       

        # calcolo del valore previsto dalla rete
        parameters_error_pred  = model(sfrd_train)

        # calcolo della loss function
        loss = loss_func(parameters_error_pred, parameters_train)
        train_loss += (loss.item())
        points     += bs

        # ottimizzazione dei parametri
        optimizer.zero_grad() # azzeramento del gradiente
        loss.backward()       # calcolo del nuovo gradiente
        optimizer.step()      # calcolo dei nuovi parametri usando l'algoritmo di ottimizzazione


    # calcolo del valor medio
    train_loss /= points
    train_value[epoch]=train_loss


    # validation
    valid_loss, points = 0.0, 0
    model.eval()
    for sfrd_val, parameters_val in valid_loader:
        with torch.no_grad():

             # dimensione del batch
            bs = sfrd_val.shape[0]

            

            # calcolo del valore previsto dalla rete
            parameters_error_pred  = model(sfrd_val)
            valid_loss += (loss_func(parameters_error_pred, parameters_val).item())
            points     += bs

    # calcolo del valore medio
    valid_loss /= points
    valid_value[epoch]=valid_loss

    scheduler.step(valid_loss)

    # ricerca del modello migliore
    print(f'epoch:{epoch}, valid loss: {valid_loss:.4f}', end='')
    if valid_loss<min_valid_loss:
        torch.save(model.state_dict(), f_model)
        min_valid_loss = valid_loss
        epoch_best_model=epoch
        print(' (best-model)')
    else:
        print('')
    if epoch - epoch_best_model > stop_criterion:
        print ('Training stop at epoch:',epoch,' because the best model does not imporved after ',stop_criterion,' epochs')
        break

stop = time.time() # spegnimento cronometro
print('Time taken (seconds):', "{:.4f}".format(stop-start))
# Out:
# epoch:0, valid loss: 0.5430 (best-model)
# epoch:1, valid loss: 0.0395 (best-model)
# epoch:2, valid loss: -0.1041 (best-model)
# epoch:3, valid loss: -0.1953 (best-model)
# epoch:4, valid loss: -0.2718 (best-model)
# epoch:5, valid loss: -0.3184 (best-model)
# epoch:6, valid loss: -0.3544 (best-model)
# epoch:7, valid loss: -0.3643 (best-model)
# epoch:8, valid loss: -0.3691 (best-model)
# epoch:9, valid loss: -0.3680
# epoch:10, valid loss: -0.3788 (best-model)
# epoch:11, valid loss: -0.3805 (best-model)
# epoch:12, valid loss: -0.3670
# epoch:13, valid loss: -0.3778
# epoch:14, valid loss: -0.3780
# epoch:15, valid loss: -0.3935 (best-model)
# epoch:16, valid loss: -0.3906
# epoch:17, valid loss: -0.3893
# epoch:18, valid loss: -0.3842
# epoch:19, valid loss: -0.3548
# epoch:20, valid loss: -0.4036 (best-model)
# epoch:21, valid loss: -0.3865
# epoch:22, valid loss: -0.4055 (best-model)
# epoch:23, valid loss: -0.4019
# epoch:24, valid loss: -0.4098 (best-model)
# epoch:25, valid loss: -0.4099 (best-model)
# epoch:26, valid loss: -0.4061
# epoch:27, valid loss: -0.4055
# epoch:28, valid loss: -0.4130 (best-model)
# epoch:29, valid loss: -0.4117
# epoch:30, valid loss: -0.4247 (best-model)
# epoch:31, valid loss: -0.4315 (best-model)
# epoch:32, valid loss: -0.4462 (best-model)
# epoch:33, valid loss: -0.4407
# epoch:34, valid loss: -0.4455
# epoch:35, valid loss: -0.4405
# epoch:36, valid loss: -0.4157
# epoch:37, valid loss: -0.4302
# epoch:38, valid loss: -0.4631 (best-model)
# epoch:39, valid loss: -0.4410
# epoch:40, valid loss: -0.4565
# epoch:41, valid loss: -0.4561
# epoch:42, valid loss: -0.4781 (best-model)
# epoch:43, valid loss: -0.4547
# epoch:44, valid loss: -0.4458
# epoch:45, valid loss: -0.4478
# epoch:46, valid loss: -0.4656
# epoch:47, valid loss: -0.4592
# epoch:48, valid loss: -0.4576
# epoch:49, valid loss: -0.4828 (best-model)
# epoch:50, valid loss: -0.4582
# epoch:51, valid loss: -0.4781
# epoch:52, valid loss: -0.4808
# epoch:53, valid loss: -0.4663
# epoch:54, valid loss: -0.4768
# epoch:55, valid loss: -0.4495
# epoch:56, valid loss: -0.4794
# epoch:57, valid loss: -0.4695
# epoch:58, valid loss: -0.4607
# epoch:59, valid loss: -0.4942 (best-model)
# epoch:60, valid loss: -0.4722
# epoch:61, valid loss: -0.4872
# epoch:62, valid loss: -0.4747
# epoch:63, valid loss: -0.4715
# epoch:64, valid loss: -0.4794
# epoch:65, valid loss: -0.4759
# epoch:66, valid loss: -0.4789
# epoch:67, valid loss: -0.4786
# epoch:68, valid loss: -0.4665
# epoch:69, valid loss: -0.4484
# epoch:70, valid loss: -0.4909
# epoch:71, valid loss: -0.4774
# epoch:72, valid loss: -0.4842
# epoch:73, valid loss: -0.4903
# epoch:74, valid loss: -0.4724
# epoch:75, valid loss: -0.5077 (best-model)
# epoch:76, valid loss: -0.5073
# epoch:77, valid loss: -0.4852
# epoch:78, valid loss: -0.4968
# epoch:79, valid loss: -0.4916
# epoch:80, valid loss: -0.4915
# epoch:81, valid loss: -0.4999
# epoch:82, valid loss: -0.4541
# epoch:83, valid loss: -0.4942
# epoch:84, valid loss: -0.5080 (best-model)
# epoch:85, valid loss: -0.5066
# epoch:86, valid loss: -0.5016
# epoch:87, valid loss: -0.5003
# epoch:88, valid loss: -0.4820
# epoch:89, valid loss: -0.4999
# epoch:90, valid loss: -0.5094 (best-model)
# epoch:91, valid loss: -0.4771
# epoch:92, valid loss: -0.5036
# epoch:93, valid loss: -0.5013
# epoch:94, valid loss: -0.5106 (best-model)
# epoch:95, valid loss: -0.4958
# epoch:96, valid loss: -0.5316 (best-model)
# epoch:97, valid loss: -0.4407
# epoch:98, valid loss: -0.5272
# epoch:99, valid loss: -0.5101
# epoch:100, valid loss: -0.5191
# epoch:101, valid loss: -0.4929
# epoch:102, valid loss: -0.5275
# epoch:103, valid loss: -0.5171
# epoch:104, valid loss: -0.4963
# epoch:105, valid loss: -0.4779
# epoch:106, valid loss: -0.4730
# epoch:107, valid loss: -0.5037
# epoch:108, valid loss: -0.5201
# epoch:109, valid loss: -0.4910
# epoch:110, valid loss: -0.5002
# epoch:111, valid loss: -0.5034
# epoch:112, valid loss: -0.4974
# epoch:113, valid loss: -0.5119
# epoch:114, valid loss: -0.5241
# epoch:115, valid loss: -0.5045
# epoch:116, valid loss: -0.5133
# epoch:117, valid loss: -0.5072
# epoch:118, valid loss: -0.5159
# epoch:119, valid loss: -0.4908
# epoch:120, valid loss: -0.4987
# epoch:121, valid loss: -0.5263
# epoch:122, valid loss: -0.4958
# epoch:123, valid loss: -0.5179
# epoch:124, valid loss: -0.5187
# epoch:125, valid loss: -0.5047
# epoch:126, valid loss: -0.5179
# epoch:127, valid loss: -0.5252
# epoch:128, valid loss: -0.5219
# epoch:129, valid loss: -0.5111
# Time taken (seconds): 30.6530

# %%
# realizzazione grafico
epoche=np.arange(epoch_best_model)

plt.plot(epoche,train_value[:epoch_best_model],label='training')
plt.plot(epoche,valid_value[:epoch_best_model],ls='--',label='validation')

plt.legend()
plt.title("loss function del training e del validation")
plt.xlabel("epoch")
plt.ylabel("loss ")
plt.show()

# %% [markdown]
# Dal grafico si osserva un andamento decrescente di entrambe le loss function. In particolare, le curve decrescono molto velocemente fino a 10 epoche, in seguito la decrescita avviene lentamente. La validation loss raggiunge un plaetau dopo circa 50 epoche e il suo valore supera quello della training loss dopo circa 60 epoche

# %% [markdown]
# Analogamente a quanto fatto prima, viene fatto un confronto tra i valori predetti dalla rete neuronale con quelli veri per il test set.

# %%
test_loader = create_dataset('test', file_sfrd, file_parameters, batch_size, seed) #test data



# test
sfrd_values=np.zeros((int(sfrd_data.shape[0]*0.15),100), dtype=np.float32)
parameters_true = np.zeros((int(parameters_data.shape[0]*0.15),6), dtype=np.float32)
parameters_NN = np.zeros((int(parameters_data.shape[0]*0.15),6), dtype=np.float32)
err_NN = np.zeros((int(parameters_data.shape[0]*0.15),6), dtype=np.float32)

offset = 0
test_loss, points = 0.0, 0
model.eval()

counter=0
for sfrd_test, parameters_test in test_loader:
    with torch.no_grad():

        bs = sfrd_test.shape[0]

        

        # calcolo dei valori previsti dalla rete
        parameters_error_pred  = model(sfrd_test)

       
        # traduzione in array Numpy

        sfrd_values[counter:counter+bs,:]=sfrd_test.numpy()
        parameters_true[counter:counter+bs,:]= parameters_test.numpy()
        parameters_NN[counter:counter+bs,:]= parameters_error_pred[:, ::2].numpy()
        err_NN[counter:counter+bs,:] = parameters_error_pred[:, 1::2].numpy()

        # compute cumulative loss and number of examples used
        test_loss += (loss_func(parameters_error_pred, parameters_test))
        points += sfrd_test.shape[0]

        counter += bs

# calcolo del valore medio
test_loss /= points

print('test loss = %.3e'%test_loss)
# Out:
# test loss = -4.979e-01

# %% [markdown]
# Vengono riportati in seguito i grafici relativi ai 6 parametri

# %%
# produzione del grafico

label = [r'$\Omega_{m}$',r'$\sigma_{8}$',r'$A_{SN1}$',r'$A_{SN2}$',r'$A_{AGN1}$',r'$A_{AGN2}$' ]

plt.figure(figsize=(9,9))

u= np.random.uniform(0, 1, 150)
#ciclo per creare griglia per ogni parametro
for j in range(6):
    plt.subplot(3, 2, j + 1)
    plt.scatter(parameters_true[:, j], parameters_NN[:, j], s = 3, color='green',alpha=0.6, marker='o')
    #eq retta y=x 
    plt.plot(u, u, color='black') 
    plt.title(label[j])
    plt.xlabel('Parametri reali')
    plt.ylabel('Stime NN')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
#sistma automaticamente il layout    
plt.tight_layout()
plt.show()

# %%
num_within_1_error = []
num_within_2_errors = []
num_within_3_errors = []

for j in range(6):  # Ciclo su ogni parametro
    # Calcoliamo la distanza euclidea normalizzata tra i punti dello scatter e la retta y = x per il parametro j
    #A, B, C = 1, -1, 0  # Coefficienti dell'equazione della bisettrice
    #distanza= np.abs(A * parameters_true[:,j] + B * parameters_NN[:,j] + C) / np.sqrt(A**2 + B**2)
    distanza = np.abs(parameters_NN[:, j] - parameters_true[:, j]) / np.sqrt(2)

    # seleziono i punti che si trovano entro 1 errore dalla retta y = x per il parametro j
    within_1_error = distanza < np.abs(1*err_NN[:,j])
    # seleziono i punti che si trovano entro 1 errore dalla retta y = x per il parametro j
    within_2_errors = distanza < np.abs(2*err_NN[:,j])
    # seleziono i punti che si trovano entro 3 errori dalla retta y = x per il parametro j
    within_3_errors = distanza < np.abs(3*err_NN[:,j])

    # Calcoliamo il numero di punti che soddisfano ciascun criterio per il parametro j
    num_within_1_error.append(np.sum(within_1_error))
    num_within_2_errors.append(np.sum(within_2_errors))
    num_within_3_errors.append(np.sum(within_3_errors))

# Stampiamo i risultati per ciascun parametro
label = ['\u03A9_m','\u03C3_{8}','A_{SN1}','A_{SN2}','A_{AGN1}','A_{AGN2}' ]
for j in range(6):
    print("Parametro:", label[j])
    print(np.abs(err_NN[:,j]))
    print("Numero di punti entro 1 errore dalla retta y = x:", num_within_1_error[j])
    print("Numero di punti entro 2 errori dalla retta y = x:", num_within_2_errors[j])
    print("Numero di punti entro 3 errori dalla retta y = x:", num_within_3_errors[j])
    print("")
# Out:
# Parametro: Ω_m
# [0.19669831 0.14868914 0.14969209 0.1533611  0.15907177 0.187341
#  0.14954686 0.17690139 0.18628255 0.19160192 0.13773869 0.15368691
#  0.18008396 0.18528867 0.15360823 0.17066295 0.181131   0.18863133
#  0.15372208 0.21154697 0.19503462 0.13211557 0.18974876 0.18416056
#  0.14066413 0.15341914 0.18992124 0.15814294 0.13571331 0.14673802
#  0.1590602  0.16221644 0.17756611 0.13747814 0.15582816 0.1345056
#  0.17064792 0.13684818 0.16504663 0.18801787 0.20590924 0.16712269
#  0.17513064 0.14735588 0.12485628 0.18944979 0.1429058  0.16564664
#  0.13716926 0.15445298 0.17604294 0.14648154 0.19039056 0.19089088
#  0.17122465 0.16410804 0.1974078  0.14218548 0.14044909 0.12530923
#  0.16726646 0.1567909  0.17675096 0.19145134 0.1675664  0.17093793
#  0.1281283  0.14244252 0.16457689 0.14687353 0.1892215  0.20119323
#  0.1596463  0.19025809 0.18877481 0.15657106 0.16736697 0.1383502
#  0.17171255 0.1583647  0.15355802 0.18994454 0.13944903 0.11374443
#  0.14203668 0.18633191 0.20492032 0.19054666 0.15306242 0.15718022
#  0.16826825 0.1558604  0.1650943  0.06264502 0.18280178 0.16564296
#  0.0817674  0.16519079 0.19070156 0.1384638  0.17998362 0.1627978
#  0.19234166 0.1499474  0.15565464 0.17460826 0.19522023 0.07433315
#  0.16785657 0.1838406  0.14758883 0.16684707 0.15651104 0.14666598
#  0.11584464 0.1695171  0.19233212 0.17335072 0.12525907 0.16540608
#  0.17518048 0.19188705 0.13463825 0.17259523 0.15471329 0.181546
#  0.15296695 0.1520745  0.15734428 0.19132942 0.18468864 0.17053878
#  0.15390182 0.18932399 0.17505082 0.17422307 0.18485941 0.16979703
#  0.18323427 0.14738107 0.16653225 0.19118391 0.18336457 0.15479833
#  0.1590729  0.18561572 0.13948265 0.03744957 0.18721595 0.15869012]
# Numero di punti entro 1 errore dalla retta y = x: 116
# Numero di punti entro 2 errori dalla retta y = x: 147
# Numero di punti entro 3 errori dalla retta y = x: 150
#
# Parametro: σ_{8}
# [0.15561073 0.11964303 0.08170554 0.1444063  0.20459743 0.14395016
#  0.21555479 0.21604885 0.2037269  0.21254312 0.19172236 0.21878703
#  0.17167959 0.18854193 0.16430947 0.19336413 0.2147636  0.18964943
#  0.14910452 0.18110931 0.19828017 0.20175847 0.17464325 0.21689196
#  0.2239678  0.19479755 0.21510626 0.2316791  0.10771203 0.13588302
#  0.21655951 0.22571535 0.21220733 0.22202177 0.21163954 0.09373139
#  0.19886467 0.18459174 0.19255857 0.18047985 0.16837871 0.22071509
#  0.14807512 0.22909851 0.13527079 0.21153562 0.20575775 0.21477486
#  0.2162335  0.17794764 0.21754788 0.16002142 0.18693523 0.20015936
#  0.1925984  0.21023421 0.1741807  0.20325662 0.1598996  0.09840575
#  0.17810738 0.207563   0.2155778  0.20656694 0.2218584  0.20930009
#  0.13297611 0.20679073 0.13843    0.17889036 0.21025254 0.16081727
#  0.21825896 0.20267576 0.21372934 0.12158148 0.17130883 0.11498761
#  0.21539657 0.19156104 0.18316995 0.22956173 0.11661886 0.18413123
#  0.19736959 0.17982854 0.20300403 0.15296136 0.21823718 0.19722985
#  0.20636229 0.21712615 0.21398886 0.1398112  0.1726317  0.21114029
#  0.0858124  0.16945691 0.16248833 0.16051473 0.20088808 0.13588418
#  0.19422175 0.15242308 0.22930707 0.16141978 0.1912059  0.12115981
#  0.21704994 0.20178153 0.16529624 0.19394642 0.13841845 0.21448953
#  0.06100791 0.2332574  0.19374034 0.18990542 0.1513964  0.17487098
#  0.22579367 0.20412497 0.17835449 0.18609856 0.18835562 0.2114409
#  0.12655647 0.2195649  0.23259304 0.19017203 0.20910104 0.21915026
#  0.14138629 0.20184617 0.15956064 0.18438943 0.21886156 0.2160023
#  0.19171456 0.12650721 0.2139243  0.21828972 0.17085025 0.14665112
#  0.23224922 0.21149613 0.12284191 0.0950361  0.16316983 0.21921046]
# Numero di punti entro 1 errore dalla retta y = x: 115
# Numero di punti entro 2 errori dalla retta y = x: 148
# Numero di punti entro 3 errori dalla retta y = x: 150
#
# Parametro: A_{SN1}
# [0.12001063 0.09979026 0.15804437 0.02283967 0.2324685  0.11786912
#  0.08873564 0.1627771  0.18052971 0.17908545 0.01426346 0.08147302
#  0.03728699 0.15588251 0.03327304 0.07612095 0.1677578  0.15839535
#  0.18823582 0.06982446 0.14239356 0.2348229  0.10560885 0.21878609
#  0.03170278 0.04322951 0.14521226 0.0762399  0.00603141 0.00127655
#  0.04846004 0.209258   0.15054107 0.09889106 0.2140728  0.04267696
#  0.16167627 0.00683774 0.21458521 0.1063735  0.09370971 0.212441
#  0.11762549 0.1883811  0.05994858 0.18043274 0.23350045 0.23125711
#  0.24636464 0.07732066 0.19684939 0.07638716 0.09185354 0.17408401
#  0.08957742 0.17864743 0.09376822 0.22894016 0.00075744 0.06147078
#  0.09053472 0.21805662 0.19349523 0.18825649 0.20507883 0.19381298
#  0.06720802 0.01104424 0.05394259 0.20893593 0.15956756 0.08290464
#  0.22346017 0.17397149 0.1735257  0.13637605 0.04877175 0.07690215
#  0.19013722 0.2031731  0.04852761 0.11999193 0.09294513 0.0819432
#  0.03122506 0.11129335 0.04802169 0.05751038 0.20136365 0.00827542
#  0.21231021 0.22896875 0.18658584 0.0054239  0.0572665  0.17194574
#  0.03994523 0.10982247 0.10730737 0.01090005 0.15725632 0.14460717
#  0.18394122 0.00543207 0.20565802 0.14020357 0.14182942 0.02997275
#  0.19102524 0.1696191  0.02723224 0.0623673  0.10032752 0.1889463
#  0.03886846 0.14003849 0.15884034 0.06242479 0.00784877 0.11457151
#  0.23156255 0.1550533  0.04280147 0.07888051 0.00330282 0.18827954
#  0.15008697 0.16632353 0.00260165 0.13928391 0.18423566 0.1995502
#  0.12063316 0.17522791 0.0680647  0.12543696 0.21054326 0.19371977
#  0.08839987 0.00510139 0.16389076 0.14063802 0.13622649 0.0270874
#  0.10342875 0.17716804 0.093339   0.02042383 0.13064194 0.1897602 ]
# Numero di punti entro 1 errore dalla retta y = x: 108
# Numero di punti entro 2 errori dalla retta y = x: 138
# Numero di punti entro 3 errori dalla retta y = x: 143
#
# Parametro: A_{SN2}
# [0.27832907 0.24145424 0.23683575 0.25636628 0.27985314 0.24402198
#  0.28624105 0.2760783  0.30437538 0.2979853  0.28399616 0.2971948
#  0.31006283 0.31316668 0.26894352 0.2846772  0.28956988 0.30083698
#  0.25749862 0.23600087 0.33174005 0.2831666  0.25872162 0.28604022
#  0.29734823 0.2907398  0.34617874 0.29367164 0.2531696  0.26057428
#  0.2686185  0.28315887 0.30789864 0.2769876  0.28584412 0.23710003
#  0.2668339  0.25911146 0.29467705 0.28856778 0.22358099 0.31415036
#  0.2905941  0.27273202 0.23455209 0.29656556 0.31687355 0.29480556
#  0.3468287  0.25683895 0.29435155 0.23592278 0.318765   0.30810606
#  0.27564368 0.2894415  0.3038086  0.26205447 0.25873768 0.21420065
#  0.26298857 0.29856053 0.29644066 0.30362174 0.2752594  0.30044943
#  0.2423136  0.2694836  0.26464906 0.28731844 0.29333875 0.225259
#  0.32000354 0.30107057 0.303537   0.24825019 0.22082555 0.235246
#  0.28517964 0.28835368 0.24293095 0.33471426 0.23328274 0.3237945
#  0.27818158 0.26501006 0.35344273 0.2889061  0.2882205  0.26570946
#  0.33231044 0.33224994 0.2807722  0.20256749 0.30900294 0.31576777
#  0.21257871 0.28164327 0.27959648 0.24970767 0.28888574 0.2474196
#  0.31448954 0.25233087 0.27053463 0.2694785  0.32488534 0.20227131
#  0.28324962 0.32615474 0.25347507 0.25775287 0.25343272 0.2999426
#  0.21738958 0.29049417 0.3185531  0.31932366 0.23978335 0.25560078
#  0.29472786 0.33326697 0.26446655 0.29031694 0.3051964  0.29012287
#  0.22956157 0.2666385  0.29348946 0.31562126 0.30159748 0.29040876
#  0.23482326 0.31428018 0.273087   0.27386364 0.29044846 0.2844178
#  0.31020993 0.25338873 0.28666922 0.33369923 0.3005023  0.2501779
#  0.30930725 0.35161644 0.23742849 0.17464575 0.26891094 0.26761797]
# Numero di punti entro 1 errore dalla retta y = x: 129
# Numero di punti entro 2 errori dalla retta y = x: 150
# Numero di punti entro 3 errori dalla retta y = x: 150
#
# Parametro: A_{AGN1}
# [0.04661941 0.09294532 0.07438773 0.12147529 0.07165684 0.04606656
#  0.05518418 0.14240286 0.14756973 0.15323009 0.1405762  0.17829831
#  0.1618824  0.07512827 0.11876681 0.15052094 0.13535704 0.14136605
#  0.08681853 0.03071414 0.08276194 0.05257822 0.03842519 0.12067319
#  0.08711614 0.16939467 0.10221392 0.13826089 0.10829781 0.11797574
#  0.09635155 0.1805779  0.07706824 0.06004609 0.07351109 0.09803942
#  0.05970823 0.09414031 0.10245501 0.13551114 0.00373648 0.04081356
#  0.12409206 0.16104355 0.09274745 0.15682644 0.04538725 0.08322088
#  0.0448641  0.08251217 0.16966045 0.06600562 0.15645257 0.15215302
#  0.15096875 0.0439625  0.14174479 0.07433808 0.13933171 0.10361233
#  0.14064698 0.02943074 0.16948709 0.14834876 0.11915778 0.0725746
#  0.09393334 0.08629027 0.11837558 0.08096656 0.1519224  0.02243902
#  0.03711144 0.13661554 0.16590917 0.07126464 0.05040348 0.10153295
#  0.15196055 0.03667458 0.0705507  0.09331533 0.10189061 0.16939436
#  0.15174122 0.13619375 0.13682818 0.1412566  0.07644559 0.10326187
#  0.0282963  0.05099249 0.1431158  0.16076443 0.15453331 0.05660618
#  0.13613331 0.10361014 0.13372707 0.10161163 0.07362075 0.06005101
#  0.14632526 0.12987876 0.10825951 0.11847857 0.14784469 0.14282885
#  0.15346244 0.10797264 0.13668036 0.08154242 0.10137892 0.05556099
#  0.10398464 0.1511365  0.14175084 0.16647504 0.11341177 0.08209296
#  0.10000946 0.08520475 0.13546829 0.15200372 0.17619947 0.15307765
#  0.05978189 0.06047593 0.0871848  0.16007861 0.16050655 0.17418659
#  0.0677525  0.14600196 0.13455316 0.03321458 0.11816044 0.15546909
#  0.16316463 0.11863174 0.14582656 0.10738696 0.1359528  0.1268542
#  0.08696645 0.11458501 0.07836831 0.13077119 0.06720462 0.13573101]
# Numero di punti entro 1 errore dalla retta y = x: 111
# Numero di punti entro 2 errori dalla retta y = x: 144
# Numero di punti entro 3 errori dalla retta y = x: 147
#
# Parametro: A_{AGN2}
# [0.2539371  0.28280288 0.29952133 0.31697863 0.28406066 0.26722226
#  0.2835062  0.29977876 0.29314125 0.2947343  0.30897444 0.26145118
#  0.25260568 0.26345193 0.34148186 0.2597837  0.2735218  0.282575
#  0.29428667 0.24553806 0.26986837 0.3068818  0.24844348 0.28320926
#  0.30124164 0.24484713 0.26238889 0.30160475 0.33852363 0.3305949
#  0.33144385 0.3063457  0.26743484 0.27954    0.27462783 0.29584992
#  0.27269894 0.33938676 0.31589615 0.28729576 0.24655393 0.32089752
#  0.30969965 0.28697932 0.31449926 0.2966049  0.30819637 0.28203893
#  0.33197427 0.3190744  0.3068899  0.3037793  0.2758398  0.2967034
#  0.28645885 0.29462877 0.24454488 0.2888767  0.31016076 0.32030183
#  0.26016784 0.33567607 0.30478942 0.30438548 0.2796257  0.26584217
#  0.32178366 0.3404336  0.30061066 0.29673272 0.29539776 0.23171052
#  0.33384532 0.27643085 0.3064217  0.30611092 0.28253633 0.30128413
#  0.29321244 0.31159413 0.31837928 0.2842911  0.3103658  0.27669594
#  0.29400188 0.26799375 0.27995598 0.25591987 0.2745672  0.33458692
#  0.3159145  0.31876588 0.28570727 0.3285252  0.23464446 0.276092
#  0.34638816 0.3088777  0.2526969  0.31313664 0.27052486 0.2819423
#  0.30756378 0.31838125 0.28082603 0.29478526 0.28324598 0.3280444
#  0.29246962 0.26392692 0.29240385 0.3063966  0.2907437  0.27929896
#  0.3139689  0.25255343 0.27757612 0.23360817 0.32969582 0.3020389
#  0.28065574 0.2834029  0.26336193 0.24132983 0.25294548 0.29627663
#  0.28701353 0.29821783 0.33483303 0.3068362  0.3024305  0.30432427
#  0.29446426 0.29183808 0.2956246  0.259789   0.2804989  0.29493833
#  0.27924794 0.31873    0.28019392 0.27252716 0.29871017 0.30721617
#  0.27245605 0.2813482  0.3063386  0.3356185  0.2849499  0.2802498 ]
# Numero di punti entro 1 errore dalla retta y = x: 125
# Numero di punti entro 2 errori dalla retta y = x: 150
# Numero di punti entro 3 errori dalla retta y = x: 150

# %% [markdown]
# Dai valori ottenuti è possibile osservare che i valori stimati con la neural network di $A_{SN2}$ e $A_{AGN2}$ sono quelli che sono stimati meglio dal modello. Sebbene dallo scatter plot sembri che  $A_{SN1}$ e $A_{AGN1}$ siano i parametri stimati meglio, contando quanti punti rientrano nell'intervallo corrispondente ad 1 deviazione standard e 3 deviazioni standard si osserva che le fasce relative ai parametri $A_{SN2}$ e $A_{AGN2}$ sono quelle che raccolgono un numero di punti maggiore.

# %% [markdown]
# Ciò è dovuto al fatto che proprio questi ultimi 2 parametri sono quelli ad avere un errore maggiore cosi' come visibile dai valori stampati.
